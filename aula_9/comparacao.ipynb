# %%
import subprocess
import time
import pandas as pd

df = pd.DataFrame(columns=['Saida','Tempo','n','Algoritmo'])

lista_program = ['../aula_5/main','../aula_6/main','../busca_local/main']
lista_programs=[]
for i in lista_program:
        lista_=[]
        for j in range(1,297):
            f = open(f'inputs/in{j}.txt',"r")
            contents = f.read()
            f.close()
            n = contents.split()[0]
            start = time.perf_counter()
            proc = subprocess.run([i], input=contents, text=True, capture_output=True)
            end = time.perf_counter()
            print('Saída:', proc.stdout)
            print("value", proc.stdout.split()[-1])
            print('Stderr:', proc.stderr)
            print('Tempo total(s):', end - start)
            dic = {
                'Tempo':float(end-start),
                'Saida':int(proc.stdout.split()[-1]),
                'n': int(n)
            }
            lista_.append(dic)
        lista_programs.append(lista_)
for i in range(len(lista_programs)):
    for j in lista_programs[i]:
        if i == 0:
            alg = 'Heuristica'
        elif i == 1:
            alg = 'Aleatorio'
        else:
            alg = 'Busca Local'
        j['Algoritmo'] = alg
        print(j)
        df = df.append(j, ignore_index = True)
# Out:
# Saída: 2 18
#
# value 18
# Stderr:
# Tempo total(s): 0.014357744000335515
# Saída: 6 12
#
# value 12
# Stderr:
# Tempo total(s): 0.013676165999640943
# Saída: 3 25
#
# value 25
# Stderr:
# Tempo total(s): 0.013486403000570135
# Saída: 5 11
#
# value 11
# Stderr:
# Tempo total(s): 0.013030481999521726
# Saída: 7 26
#
# value 26
# Stderr:
# Tempo total(s): 0.013453689999550988
# Saída: 2 20
#
# value 20
# Stderr:
# Tempo total(s): 0.013739192000684852
# Saída: 8 41
#
# value 41
# Stderr:
# Tempo total(s): 0.012759864999679849
# Saída: 13 29
#
# value 29
# Stderr:
# Tempo total(s): 0.012828616999286169
# Saída: 17 61
#
# value 61
# Stderr:
# Tempo total(s): 0.012870764000581403
# Saída: 4 39
#
# value 39
# Stderr:
# Tempo total(s): 0.012745443999847339
# Saída: 28 155
#
# value 155
# Stderr:
# Tempo total(s): 0.012916788999973505
# Saída: 22 58
#
# value 58
# Stderr:
# Tempo total(s): 0.012795093999557139
# Saída: 7 83
#
# value 83
# Stderr:
# Tempo total(s): 0.01287072699960845
# Saída: 30 56
#
# value 56
# Stderr:
# Tempo total(s): 0.012938959000166506
# Saída: 15 75
#
# value 75
# Stderr:
# Tempo total(s): 0.012871582000116177
# Saída: 32 208
#
# value 208
# Stderr:
# Tempo total(s): 0.013912601999436447
# Saída: 13 126
#
# value 126
# Stderr:
# Tempo total(s): 0.013264637000247603
# Saída: 30 111
#
# value 111
# Stderr:
# Tempo total(s): 0.013757352000538958
# Saída: 21 126
#
# value 126
# Stderr:
# Tempo total(s): 0.013082581000162463
# Saída: 6 119
#
# value 119
# Stderr:
# Tempo total(s): 0.013136259999555477
# Saída: 45 487
#
# value 487
# Stderr:
# Tempo total(s): 0.012907615000585793
# Saída: 60 603
#
# value 603
# Stderr:
# Tempo total(s): 0.013110947999848577
# Saída: 16 120
#
# value 120
# Stderr:
# Tempo total(s): 0.012945422000484541
# Saída: 2 48
#
# value 48
# Stderr:
# Tempo total(s): 0.012840248999964388
# Saída: 52 628
#
# value 628
# Stderr:
# Tempo total(s): 0.013769986000625067
# Saída: 38 232
#
# value 232
# Stderr:
# Tempo total(s): 0.012900145999992674
# Saída: 14 173
#
# value 173
# Stderr:
# Tempo total(s): 0.012990514000193798
# Saída: 72 433
#
# value 433
# Stderr:
# Tempo total(s): 0.012898732999929052
# Saída: 29 153
#
# value 153
# Stderr:
# Tempo total(s): 0.013234819999524916
# Saída: 34 130
#
# value 130
# Stderr:
# Tempo total(s): 0.016394735000176297
# Saída: 76 796
#
# value 796
# Stderr:
# Tempo total(s): 0.013959126000372635
# Saída: 45 245
#
# value 245
# Stderr:
# Tempo total(s): 0.01294996600063314
# Saída: 18 132
#
# value 132
# Stderr:
# Tempo total(s): 0.01260295199972461
# Saída: 36 330
#
# value 330
# Stderr:
# Tempo total(s): 0.012598489000083646
# Saída: 37 221
#
# value 221
# Stderr:
# Tempo total(s): 0.012437868999768398
# Saída: 28 189
#
# value 189
# Stderr:
# Tempo total(s): 0.01261225599955651
# Saída: 19 312
#
# value 312
# Stderr:
# Tempo total(s): 0.012564214000121865
# Saída: 29 257
#
# value 257
# Stderr:
# Tempo total(s): 0.012568126999212836
# Saída: 31 570
#
# value 570
# Stderr:
# Tempo total(s): 0.012525467999694229
# Saída: 5 381
#
# value 381
# Stderr:
# Tempo total(s): 0.012781524000274658
# Saída: 27 192
#
# value 192
# Stderr:
# Tempo total(s): 0.01267907799956447
# Saída: 58 279
#
# value 279
# Stderr:
# Tempo total(s): 0.012735249999423104
# Saída: 51 249
#
# value 249
# Stderr:
# Tempo total(s): 0.013641047000419348
# Saída: 3 111
#
# value 111
# Stderr:
# Tempo total(s): 0.014048294000531314
# Saída: 36 469
#
# value 469
# Stderr:
# Tempo total(s): 0.014558836999640334
# Saída: 18 364
#
# value 364
# Stderr:
# Tempo total(s): 0.012882775000434776
# Saída: 37 254
#
# value 254
# Stderr:
# Tempo total(s): 0.012677565000558388
# Saída: 23 272
#
# value 272
# Stderr:
# Tempo total(s): 0.012370982999527769
# Saída: 64 436
#
# value 436
# Stderr:
# Tempo total(s): 0.012747286000376334
# Saída: 47 448
#
# value 448
# Stderr:
# Tempo total(s): 0.013688861000446195
# Saída: 101 789
#
# value 789
# Stderr:
# Tempo total(s): 0.014044161000128952
# Saída: 11 130
#
# value 130
# Stderr:
# Tempo total(s): 0.01352406699970743
# Saída: 48 340
#
# value 340
# Stderr:
# Tempo total(s): 0.012853240000367805
# Saída: 20 86
#
# value 86
# Stderr:
# Tempo total(s): 0.013144915999873774
# Saída: 1 134
#
# value 134
# Stderr:
# Tempo total(s): 0.01323854400015989
# Saída: 55 892
#
# value 892
# Stderr:
# Tempo total(s): 0.013480972000252223
# Saída: 89 857
#
# value 857
# Stderr:
# Tempo total(s): 0.013979374999507854
# Saída: 5 88
#
# value 88
# Stderr:
# Tempo total(s): 0.014134370000647323
# Saída: 14 453
#
# value 453
# Stderr:
# Tempo total(s): 0.013932034999925236
# Saída: 58 420
#
# value 420
# Stderr:
# Tempo total(s): 0.013572605000263138
# Saída: 61 434
#
# value 434
# Stderr:
# Tempo total(s): 0.013913408999542298
# Saída: 31 200
#
# value 200
# Stderr:
# Tempo total(s): 0.013357499999983702
# Saída: 2 221
#
# value 221
# Stderr:
# Tempo total(s): 0.012731379999422643
# Saída: 110 1297
#
# value 1297
# Stderr:
# Tempo total(s): 0.012660811999921862
# Saída: 30 401
#
# value 401
# Stderr:
# Tempo total(s): 0.012928046000524773
# Saída: 139 1750
#
# value 1750
# Stderr:
# Tempo total(s): 0.012702961999821127
# Saída: 115 748
#
# value 748
# Stderr:
# Tempo total(s): 0.012707158999546664
# Saída: 25 359
#
# value 359
# Stderr:
# Tempo total(s): 0.012610398999640893
# Saída: 77 709
#
# value 709
# Stderr:
# Tempo total(s): 0.012819935000152327
# Saída: 62 1052
#
# value 1052
# Stderr:
# Tempo total(s): 0.014018998000210559
# Saída: 106 1502
#
# value 1502
# Stderr:
# Tempo total(s): 0.015366622000328789
# Saída: 45 456
#
# value 456
# Stderr:
# Tempo total(s): 0.012235975000294275
# Saída: 108 1321
#
# value 1321
# Stderr:
# Tempo total(s): 0.012289510000300652
# Saída: 88 1560
#
# value 1560
# Stderr:
# Tempo total(s): 0.012316862000261608
# Saída: 20 543
#
# value 543
# Stderr:
# Tempo total(s): 0.012255871999514056
# Saída: 74 938
#
# value 938
# Stderr:
# Tempo total(s): 0.012273836000531446
# Saída: 68 866
#
# value 866
# Stderr:
# Tempo total(s): 0.013819908000186842
# Saída: 149 1755
#
# value 1755
# Stderr:
# Tempo total(s): 0.012960871000359475
# Saída: 20 971
#
# value 971
# Stderr:
# Tempo total(s): 0.012983466000150656
# Saída: 146 1400
#
# value 1400
# Stderr:
# Tempo total(s): 0.013488458000210812
# Saída: 130 877
#
# value 877
# Stderr:
# Tempo total(s): 0.013094995000756171
# Saída: 120 1132
#
# value 1132
# Stderr:
# Tempo total(s): 0.012970131999281875
# Saída: 78 751
#
# value 751
# Stderr:
# Tempo total(s): 0.013363126000513148
# Saída: 50 972
#
# value 972
# Stderr:
# Tempo total(s): 0.013483778999216156
# Saída: 64 789
#
# value 789
# Stderr:
# Tempo total(s): 0.013460385999678692
# Saída: 219 1209
#
# value 1209
# Stderr:
# Tempo total(s): 0.013044448999607994
# Saída: 99 1512
#
# value 1512
# Stderr:
# Tempo total(s): 0.014148968000881723
# Saída: 45 447
#
# value 447
# Stderr:
# Tempo total(s): 0.01344487799997296
# Saída: 97 1234
#
# value 1234
# Stderr:
# Tempo total(s): 0.01354199300021719
# Saída: 106 2623
#
# value 2623
# Stderr:
# Tempo total(s): 0.013477740999405796
# Saída: 149 1993
#
# value 1993
# Stderr:
# Tempo total(s): 0.013779210999928182
# Saída: 74 1453
#
# value 1453
# Stderr:
# Tempo total(s): 0.01323545200011722
# Saída: 33 1199
#
# value 1199
# Stderr:
# Tempo total(s): 0.013839752999956545
# Saída: 70 774
#
# value 774
# Stderr:
# Tempo total(s): 0.013457914999889908
# Saída: 110 1341
#
# value 1341
# Stderr:
# Tempo total(s): 0.013816699999551929
# Saída: 59 815
#
# value 815
# Stderr:
# Tempo total(s): 0.01316175900046801
# Saída: 86 732
#
# value 732
# Stderr:
# Tempo total(s): 0.012813268000172684
# Saída: 71 1143
#
# value 1143
# Stderr:
# Tempo total(s): 0.012570490000143764
# Saída: 137 1837
#
# value 1837
# Stderr:
# Tempo total(s): 0.012731556000289856
# Saída: 142 1603
#
# value 1603
# Stderr:
# Tempo total(s): 0.015304352999919502
# Saída: 178 2118
#
# value 2118
# Stderr:
# Tempo total(s): 0.013230117000603059
# Saída: 40 513
#
# value 513
# Stderr:
# Tempo total(s): 0.013799809000374808
# Saída: 236 4528
#
# value 4528
# Stderr:
# Tempo total(s): 0.01367141700029606
# Saída: 102 1409
#
# value 1409
# Stderr:
# Tempo total(s): 0.014243984999666282
# Saída: 202 2285
#
# value 2285
# Stderr:
# Tempo total(s): 0.01347264199921483
# Saída: 124 2764
#
# value 2764
# Stderr:
# Tempo total(s): 0.01335639899934904
# Saída: 225 2657
#
# value 2657
# Stderr:
# Tempo total(s): 0.013125229999786825
# Saída: 43 1055
#
# value 1055
# Stderr:
# Tempo total(s): 0.013325126999916392
# Saída: 221 1018
#
# value 1018
# Stderr:
# Tempo total(s): 0.013698034999833908
# Saída: 87 1180
#
# value 1180
# Stderr:
# Tempo total(s): 0.013546996999139083
# Saída: 62 1724
#
# value 1724
# Stderr:
# Tempo total(s): 0.013507554000170785
# Saída: 52 1027
#
# value 1027
# Stderr:
# Tempo total(s): 0.013216840000495722
# Saída: 9 213
#
# value 213
# Stderr:
# Tempo total(s): 0.013810746999297407
# Saída: 234 1858
#
# value 1858
# Stderr:
# Tempo total(s): 0.013279971999509144
# Saída: 58 1516
#
# value 1516
# Stderr:
# Tempo total(s): 0.012900067000373383
# Saída: 134 1057
#
# value 1057
# Stderr:
# Tempo total(s): 0.014577755000573234
# Saída: 38 684
#
# value 684
# Stderr:
# Tempo total(s): 0.013776218000202789
# Saída: 5 153
#
# value 153
# Stderr:
# Tempo total(s): 0.012903611999718123
# Saída: 140 2703
#
# value 2703
# Stderr:
# Tempo total(s): 0.012649377999878197
# Saída: 164 4293
#
# value 4293
# Stderr:
# Tempo total(s): 0.013472645000547345
# Saída: 17 336
#
# value 336
# Stderr:
# Tempo total(s): 0.012976025999705598
# Saída: 149 330
#
# value 330
# Stderr:
# Tempo total(s): 0.013465064000229177
# Saída: 150 2698
#
# value 2698
# Stderr:
# Tempo total(s): 0.012629584999558574
# Saída: 157 1836
#
# value 1836
# Stderr:
# Tempo total(s): 0.01272916199923202
# Saída: 55 712
#
# value 712
# Stderr:
# Tempo total(s): 0.013068866000139678
# Saída: 305 2610
#
# value 2610
# Stderr:
# Tempo total(s): 0.012506281999776547
# Saída: 47 1694
#
# value 1694
# Stderr:
# Tempo total(s): 0.012779153999872506
# Saída: 129 1811
#
# value 1811
# Stderr:
# Tempo total(s): 0.012570079999932204
# Saída: 214 3358
#
# value 3358
# Stderr:
# Tempo total(s): 0.015090073999999731
# Saída: 23 509
#
# value 509
# Stderr:
# Tempo total(s): 0.013053055999989738
# Saída: 206 2059
#
# value 2059
# Stderr:
# Tempo total(s): 0.01284226099960506
# Saída: 272 1448
#
# value 1448
# Stderr:
# Tempo total(s): 0.013128812999639194
# Saída: 145 1520
#
# value 1520
# Stderr:
# Tempo total(s): 0.012994873000025109
# Saída: 93 1230
#
# value 1230
# Stderr:
# Tempo total(s): 0.012679004999881727
# Saída: 247 2242
#
# value 2242
# Stderr:
# Tempo total(s): 0.012954339000316395
# Saída: 53 1029
#
# value 1029
# Stderr:
# Tempo total(s): 0.012767759000780643
# Saída: 14 1347
#
# value 1347
# Stderr:
# Tempo total(s): 0.012430879000021378
# Saída: 101 2417
#
# value 2417
# Stderr:
# Tempo total(s): 0.012708747999568004
# Saída: 170 1772
#
# value 1772
# Stderr:
# Tempo total(s): 0.01275350800005981
# Saída: 278 1909
#
# value 1909
# Stderr:
# Tempo total(s): 0.01251828100066632
# Saída: 67 1646
#
# value 1646
# Stderr:
# Tempo total(s): 0.013154274000044097
# Saída: 91 696
#
# value 696
# Stderr:
# Tempo total(s): 0.013336295999579306
# Saída: 6 179
#
# value 179
# Stderr:
# Tempo total(s): 0.012553476999528357
# Saída: 116 1930
#
# value 1930
# Stderr:
# Tempo total(s): 0.012942152000505303
# Saída: 13 495
#
# value 495
# Stderr:
# Tempo total(s): 0.013351235999834898
# Saída: 212 1587
#
# value 1587
# Stderr:
# Tempo total(s): 0.013200656000663002
# Saída: 353 3696
#
# value 3696
# Stderr:
# Tempo total(s): 0.013698980000299343
# Saída: 283 3027
#
# value 3027
# Stderr:
# Tempo total(s): 0.013087364000057278
# Saída: 115 3334
#
# value 3334
# Stderr:
# Tempo total(s): 0.013572297000791878
# Saída: 216 1688
#
# value 1688
# Stderr:
# Tempo total(s): 0.013072173999717052
# Saída: 157 3449
#
# value 3449
# Stderr:
# Tempo total(s): 0.01239231399995333
# Saída: 230 1893
#
# value 1893
# Stderr:
# Tempo total(s): 0.012937618999785627
# Saída: 138 3219
#
# value 3219
# Stderr:
# Tempo total(s): 0.012879283000074793
# Saída: 49 1414
#
# value 1414
# Stderr:
# Tempo total(s): 0.012413649999871268
# Saída: 40 1022
#
# value 1022
# Stderr:
# Tempo total(s): 0.013104564000059327
# Saída: 3 368
#
# value 368
# Stderr:
# Tempo total(s): 0.012592671999300364
# Saída: 4 656
#
# value 656
# Stderr:
# Tempo total(s): 0.012798953000128677
# Saída: 136 2470
#
# value 2470
# Stderr:
# Tempo total(s): 0.012285453000004054
# Saída: 149 2354
#
# value 2354
# Stderr:
# Tempo total(s): 0.013169556000320881
# Saída: 106 3002
#
# value 3002
# Stderr:
# Tempo total(s): 0.013227637999989383
# Saída: 146 1527
#
# value 1527
# Stderr:
# Tempo total(s): 0.012735917000100017
# Saída: 95 2120
#
# value 2120
# Stderr:
# Tempo total(s): 0.01268689100015763
# Saída: 33 1606
#
# value 1606
# Stderr:
# Tempo total(s): 0.01305032999971445
# Saída: 328 3174
#
# value 3174
# Stderr:
# Tempo total(s): 0.012663458000133687
# Saída: 32 1969
#
# value 1969
# Stderr:
# Tempo total(s): 0.012436334999620158
# Saída: 114 1760
#
# value 1760
# Stderr:
# Tempo total(s): 0.012563379000312125
# Saída: 252 2091
#
# value 2091
# Stderr:
# Tempo total(s): 0.012582272000145167
# Saída: 140 3714
#
# value 3714
# Stderr:
# Tempo total(s): 0.01300412500040693
# Saída: 205 1220
#
# value 1220
# Stderr:
# Tempo total(s): 0.012496024000029138
# Saída: 39 1412
#
# value 1412
# Stderr:
# Tempo total(s): 0.013079096000183199
# Saída: 200 662
#
# value 662
# Stderr:
# Tempo total(s): 0.01301170000078855
# Saída: 35 1330
#
# value 1330
# Stderr:
# Tempo total(s): 0.01260939299936581
# Saída: 340 6827
#
# value 6827
# Stderr:
# Tempo total(s): 0.012702445000286389
# Saída: 156 2019
#
# value 2019
# Stderr:
# Tempo total(s): 0.0134848020006757
# Saída: 140 1473
#
# value 1473
# Stderr:
# Tempo total(s): 0.012949592999575543
# Saída: 146 2109
#
# value 2109
# Stderr:
# Tempo total(s): 0.011786281999775383
# Saída: 253 3529
#
# value 3529
# Stderr:
# Tempo total(s): 0.012131538999710756
# Saída: 160 1640
#
# value 1640
# Stderr:
# Tempo total(s): 0.012003425000330026
# Saída: 107 4237
#
# value 4237
# Stderr:
# Tempo total(s): 0.011907859000530152
# Saída: 281 3985
#
# value 3985
# Stderr:
# Tempo total(s): 0.012294015999941621
# Saída: 227 7825
#
# value 7825
# Stderr:
# Tempo total(s): 0.011909715000001597
# Saída: 33 2736
#
# value 2736
# Stderr:
# Tempo total(s): 0.012008046000119066
# Saída: 209 6152
#
# value 6152
# Stderr:
# Tempo total(s): 0.011974075999205525
# Saída: 58 5798
#
# value 5798
# Stderr:
# Tempo total(s): 0.011986541999249312
# Saída: 173 3530
#
# value 3530
# Stderr:
# Tempo total(s): 0.013836084000104165
# Saída: 133 1972
#
# value 1972
# Stderr:
# Tempo total(s): 0.013174959999560087
# Saída: 263 2120
#
# value 2120
# Stderr:
# Tempo total(s): 0.01198743100030697
# Saída: 498 5058
#
# value 5058
# Stderr:
# Tempo total(s): 0.012121674999434617
# Saída: 28 593
#
# value 593
# Stderr:
# Tempo total(s): 0.012031143000058364
# Saída: 135 3897
#
# value 3897
# Stderr:
# Tempo total(s): 0.012482549999731418
# Saída: 413 3373
#
# value 3373
# Stderr:
# Tempo total(s): 0.011830813999949896
# Saída: 101 3298
#
# value 3298
# Stderr:
# Tempo total(s): 0.01211935999981506
# Saída: 252 4982
#
# value 4982
# Stderr:
# Tempo total(s): 0.012266012000509363
# Saída: 164 2258
#
# value 2258
# Stderr:
# Tempo total(s): 0.012337416000264056
# Saída: 91 1674
#
# value 1674
# Stderr:
# Tempo total(s): 0.012410141000145813
# Saída: 90 2554
#
# value 2554
# Stderr:
# Tempo total(s): 0.01271828600056324
# Saída: 196 1518
#
# value 1518
# Stderr:
# Tempo total(s): 0.011837265999929514
# Saída: 308 3697
#
# value 3697
# Stderr:
# Tempo total(s): 0.012110468000173569
# Saída: 177 2277
#
# value 2277
# Stderr:
# Tempo total(s): 0.012401408000187075
# Saída: 211 2943
#
# value 2943
# Stderr:
# Tempo total(s): 0.012128695999308547
# Saída: 124 3149
#
# value 3149
# Stderr:
# Tempo total(s): 0.012156406000030984
# Saída: 422 9205
#
# value 9205
# Stderr:
# Tempo total(s): 0.01228708800044842
# Saída: 406 4946
#
# value 4946
# Stderr:
# Tempo total(s): 0.012039221999657457
# Saída: 244 2375
#
# value 2375
# Stderr:
# Tempo total(s): 0.012019297999358969
# Saída: 187 3035
#
# value 3035
# Stderr:
# Tempo total(s): 0.013210027999775775
# Saída: 41 479
#
# value 479
# Stderr:
# Tempo total(s): 0.012013016999844695
# Saída: 283 6053
#
# value 6053
# Stderr:
# Tempo total(s): 0.011995785999715736
# Saída: 239 3311
#
# value 3311
# Stderr:
# Tempo total(s): 0.012435360999916156
# Saída: 186 1112
#
# value 1112
# Stderr:
# Tempo total(s): 0.01196720100051607
# Saída: 107 3691
#
# value 3691
# Stderr:
# Tempo total(s): 0.012328527000136091
# Saída: 525 6731
#
# value 6731
# Stderr:
# Tempo total(s): 0.012000003999673936
# Saída: 115 5764
#
# value 5764
# Stderr:
# Tempo total(s): 0.011928420000003825
# Saída: 238 2880
#
# value 2880
# Stderr:
# Tempo total(s): 0.01191222099987499
# Saída: 80 1437
#
# value 1437
# Stderr:
# Tempo total(s): 0.012130080000133603
# Saída: 117 6035
#
# value 6035
# Stderr:
# Tempo total(s): 0.012087675000657327
# Saída: 215 1679
#
# value 1679
# Stderr:
# Tempo total(s): 0.01282834600078786
# Saída: 360 3326
#
# value 3326
# Stderr:
# Tempo total(s): 0.012402406999171944
# Saída: 407 3958
#
# value 3958
# Stderr:
# Tempo total(s): 0.012001400999906764
# Saída: 167 1664
#
# value 1664
# Stderr:
# Tempo total(s): 0.012208782999550749
# Saída: 342 6562
#
# value 6562
# Stderr:
# Tempo total(s): 0.0129865669996434
# Saída: 209 980
#
# value 980
# Stderr:
# Tempo total(s): 0.011627577000581368
# Saída: 97 3848
#
# value 3848
# Stderr:
# Tempo total(s): 0.011779044999457255
# Saída: 93 1738
#
# value 1738
# Stderr:
# Tempo total(s): 0.011770480999985011
# Saída: 60 1694
#
# value 1694
# Stderr:
# Tempo total(s): 0.011685468999530713
# Saída: 205 3280
#
# value 3280
# Stderr:
# Tempo total(s): 0.012612814999556576
# Saída: 476 4276
#
# value 4276
# Stderr:
# Tempo total(s): 0.012128265999308496
# Saída: 413 4426
#
# value 4426
# Stderr:
# Tempo total(s): 0.011800747999586747
# Saída: 212 5713
#
# value 5713
# Stderr:
# Tempo total(s): 0.011882933999913803
# Saída: 141 732
#
# value 732
# Stderr:
# Tempo total(s): 0.011784428000282787
# Saída: 45 2802
#
# value 2802
# Stderr:
# Tempo total(s): 0.011679323999487679
# Saída: 236 1691
#
# value 1691
# Stderr:
# Tempo total(s): 0.011687029999848164
# Saída: 563 4745
#
# value 4745
# Stderr:
# Tempo total(s): 0.011795548000009148
# Saída: 535 5641
#
# value 5641
# Stderr:
# Tempo total(s): 0.012090895000255841
# Saída: 456 4763
#
# value 4763
# Stderr:
# Tempo total(s): 0.011706001999300497
# Saída: 569 4580
#
# value 4580
# Stderr:
# Tempo total(s): 0.012414011000146274
# Saída: 385 9274
#
# value 9274
# Stderr:
# Tempo total(s): 0.012327889000516734
# Saída: 30 1943
#
# value 1943
# Stderr:
# Tempo total(s): 0.012236668000696227
# Saída: 218 2131
#
# value 2131
# Stderr:
# Tempo total(s): 0.011838784999781637
# Saída: 105 2842
#
# value 2842
# Stderr:
# Tempo total(s): 0.011853526999402675
# Saída: 146 3426
#
# value 3426
# Stderr:
# Tempo total(s): 0.011912138999832678
# Saída: 190 5471
#
# value 5471
# Stderr:
# Tempo total(s): 0.011690735999764001
# Saída: 374 5475
#
# value 5475
# Stderr:
# Tempo total(s): 0.011791583000558603
# Saída: 26 1502
#
# value 1502
# Stderr:
# Tempo total(s): 0.011760020000110671
# Saída: 574 5440
#
# value 5440
# Stderr:
# Tempo total(s): 0.011783897999521287
# Saída: 241 3421
#
# value 3421
# Stderr:
# Tempo total(s): 0.011612379999860423
# Saída: 165 5137
#
# value 5137
# Stderr:
# Tempo total(s): 0.011829187000330421
# Saída: 596 7912
#
# value 7912
# Stderr:
# Tempo total(s): 0.011794711000220559
# Saída: 313 2435
#
# value 2435
# Stderr:
# Tempo total(s): 0.011846077999507543
# Saída: 111 2362
#
# value 2362
# Stderr:
# Tempo total(s): 0.011784313000134716
# Saída: 374 6520
#
# value 6520
# Stderr:
# Tempo total(s): 0.011886799000421888
# Saída: 22 967
#
# value 967
# Stderr:
# Tempo total(s): 0.012135529000261158
# Saída: 72 1279
#
# value 1279
# Stderr:
# Tempo total(s): 0.013777164000202902
# Saída: 457 8331
#
# value 8331
# Stderr:
# Tempo total(s): 0.011781889999838313
# Saída: 122 1461
#
# value 1461
# Stderr:
# Tempo total(s): 0.012340086000222072
# Saída: 65 906
#
# value 906
# Stderr:
# Tempo total(s): 0.013369117000365804
# Saída: 118 907
#
# value 907
# Stderr:
# Tempo total(s): 0.012198337999507203
# Saída: 14 932
#
# value 932
# Stderr:
# Tempo total(s): 0.012248977999661292
# Saída: 145 2860
#
# value 2860
# Stderr:
# Tempo total(s): 0.012368507000246609
# Saída: 26 2475
#
# value 2475
# Stderr:
# Tempo total(s): 0.011885188000633207
# Saída: 351 2070
#
# value 2070
# Stderr:
# Tempo total(s): 0.012416943999596697
# Saída: 38 851
#
# value 851
# Stderr:
# Tempo total(s): 0.012297554000724631
# Saída: 261 4772
#
# value 4772
# Stderr:
# Tempo total(s): 0.01217122400066728
# Saída: 8 750
#
# value 750
# Stderr:
# Tempo total(s): 0.012113070000850712
# Saída: 513 5991
#
# value 5991
# Stderr:
# Tempo total(s): 0.012424313000337861
# Saída: 255 8319
#
# value 8319
# Stderr:
# Tempo total(s): 0.012119104000703373
# Saída: 57 1403
#
# value 1403
# Stderr:
# Tempo total(s): 0.012042332999953942
# Saída: 107 1564
#
# value 1564
# Stderr:
# Tempo total(s): 0.013056589999905555
# Saída: 202 3533
#
# value 3533
# Stderr:
# Tempo total(s): 0.012326124999162857
# Saída: 49 2862
#
# value 2862
# Stderr:
# Tempo total(s): 0.01331518499955564
# Saída: 232 5082
#
# value 5082
# Stderr:
# Tempo total(s): 0.012998461000279349
# Saída: 320 5091
#
# value 5091
# Stderr:
# Tempo total(s): 0.012249956000232487
# Saída: 173 3201
#
# value 3201
# Stderr:
# Tempo total(s): 0.01277503399978741
# Saída: 67 700
#
# value 700
# Stderr:
# Tempo total(s): 0.01200857999992877
# Saída: 213 3049
#
# value 3049
# Stderr:
# Tempo total(s): 0.012084282000614621
# Saída: 135 4731
#
# value 4731
# Stderr:
# Tempo total(s): 0.012123276000238548
# Saída: 92 5083
#
# value 5083
# Stderr:
# Tempo total(s): 0.0123628009996537
# Saída: 206 2017
#
# value 2017
# Stderr:
# Tempo total(s): 0.01233074999981909
# Saída: 27 2040
#
# value 2040
# Stderr:
# Tempo total(s): 0.01284828300049412
# Saída: 580 5876
#
# value 5876
# Stderr:
# Tempo total(s): 0.01225425400025415
# Saída: 64 1442
#
# value 1442
# Stderr:
# Tempo total(s): 0.012074475000190432
# Saída: 7 902
#
# value 902
# Stderr:
# Tempo total(s): 0.013191471000027377
# Saída: 824 8580
#
# value 8580
# Stderr:
# Tempo total(s): 0.013100584000312665
# Saída: 61 6260
#
# value 6260
# Stderr:
# Tempo total(s): 0.012580622999848856
# Saída: 212 2978
#
# value 2978
# Stderr:
# Tempo total(s): 0.012947764999807987
# Saída: 244 6463
#
# value 6463
# Stderr:
# Tempo total(s): 0.01187322499936272
# Saída: 85 2689
#
# value 2689
# Stderr:
# Tempo total(s): 0.012529346000519581
# Saída: 528 7915
#
# value 7915
# Stderr:
# Tempo total(s): 0.012291871999877912
# Saída: 94 4145
#
# value 4145
# Stderr:
# Tempo total(s): 0.012515333999544964
# Saída: 177 4617
#
# value 4617
# Stderr:
# Tempo total(s): 0.012363980999907653
# Saída: 308 4101
#
# value 4101
# Stderr:
# Tempo total(s): 0.01252153699988412
# Saída: 267 3680
#
# value 3680
# Stderr:
# Tempo total(s): 0.012533500000245112
# Saída: 123 3801
#
# value 3801
# Stderr:
# Tempo total(s): 0.012385470000481291
# Saída: 126 3332
#
# value 3332
# Stderr:
# Tempo total(s): 0.011986298999545397
# Saída: 441 9001
#
# value 9001
# Stderr:
# Tempo total(s): 0.012137749000430631
# Saída: 656 10085
#
# value 10085
# Stderr:
# Tempo total(s): 0.012054576000082307
# Saída: 200 3586
#
# value 3586
# Stderr:
# Tempo total(s): 0.012386139000227558
# Saída: 2 18
#
# value 18
# Stderr:
# Tempo total(s): 0.012466677999327658
# Saída: 6 12
#
# value 12
# Stderr:
# Tempo total(s): 0.01216065299922775
# Saída: 3 25
#
# value 25
# Stderr:
# Tempo total(s): 0.012190192999696592
# Saída: 5 8
#
# value 8
# Stderr:
# Tempo total(s): 0.012002256999949168
# Saída: 7 26
#
# value 26
# Stderr:
# Tempo total(s): 0.011696534000293468
# Saída: 2 20
#
# value 20
# Stderr:
# Tempo total(s): 0.012001056000372046
# Saída: 7 27
#
# value 27
# Stderr:
# Tempo total(s): 0.011862597000799724
# Saída: 13 29
#
# value 29
# Stderr:
# Tempo total(s): 0.012640329000532802
# Saída: 14 35
#
# value 35
# Stderr:
# Tempo total(s): 0.012574518999826978
# Saída: 4 39
#
# value 39
# Stderr:
# Tempo total(s): 0.012352851999821723
# Saída: 26 175
#
# value 175
# Stderr:
# Tempo total(s): 0.01188574499974493
# Saída: 22 58
#
# value 58
# Stderr:
# Tempo total(s): 0.012041031000080693
# Saída: 5 62
#
# value 62
# Stderr:
# Tempo total(s): 0.011794860999543744
# Saída: 30 56
#
# value 56
# Stderr:
# Tempo total(s): 0.012390262000735675
# Saída: 16 77
#
# value 77
# Stderr:
# Tempo total(s): 0.01176726000085182
# Saída: 32 208
#
# value 208
# Stderr:
# Tempo total(s): 0.012905864999993355
# Saída: 13 126
#
# value 126
# Stderr:
# Tempo total(s): 0.013318641000296338
# Saída: 30 111
#
# value 111
# Stderr:
# Tempo total(s): 0.012372098000014375
# Saída: 21 138
#
# value 138
# Stderr:
# Tempo total(s): 0.012432849000106216
# Saída: 6 119
#
# value 119
# Stderr:
# Tempo total(s): 0.012081077999937406
# Saída: 39 356
#
# value 356
# Stderr:
# Tempo total(s): 0.012011389999315725
# Saída: 70 542
#
# value 542
# Stderr:
# Tempo total(s): 0.012093545000425365
# Saída: 16 138
#
# value 138
# Stderr:
# Tempo total(s): 0.012331076000009489
# Saída: 2 48
#
# value 48
# Stderr:
# Tempo total(s): 0.011872903000039514
# Saída: 53 578
#
# value 578
# Stderr:
# Tempo total(s): 0.012393400000291876
# Saída: 38 173
#
# value 173
# Stderr:
# Tempo total(s): 0.013103006000164896
# Saída: 14 124
#
# value 124
# Stderr:
# Tempo total(s): 0.012137585999880685
# Saída: 55 269
#
# value 269
# Stderr:
# Tempo total(s): 0.012190088000352262
# Saída: 26 150
#
# value 150
# Stderr:
# Tempo total(s): 0.012592240000230959
# Saída: 33 79
#
# value 79
# Stderr:
# Tempo total(s): 0.01260732500031736
# Saída: 76 796
#
# value 796
# Stderr:
# Tempo total(s): 0.01224305599953368
# Saída: 45 245
#
# value 245
# Stderr:
# Tempo total(s): 0.012341257000116457
# Saída: 18 132
#
# value 132
# Stderr:
# Tempo total(s): 0.012953090999872074
# Saída: 36 218
#
# value 218
# Stderr:
# Tempo total(s): 0.011959897000451747
# Saída: 37 221
#
# value 221
# Stderr:
# Tempo total(s): 0.012064671000189264
# Saída: 27 110
#
# value 110
# Stderr:
# Tempo total(s): 0.012215502999424643
# Saída: 19 308
#
# value 308
# Stderr:
# Tempo total(s): 0.011732914999811328
# Saída: 29 150
#
# value 150
# Stderr:
# Tempo total(s): 0.01209852099964337
# Saída: 30 375
#
# value 375
# Stderr:
# Tempo total(s): 0.012554163999993762
# Saída: 3 251
#
# value 251
# Stderr:
# Tempo total(s): 0.011875488999976369
# Saída: 36 154
#
# value 154
# Stderr:
# Tempo total(s): 0.012173418000202219
# Saída: 58 243
#
# value 243
# Stderr:
# Tempo total(s): 0.012146045000008598
# Saída: 51 249
#
# value 249
# Stderr:
# Tempo total(s): 0.01217971000005491
# Saída: 3 111
#
# value 111
# Stderr:
# Tempo total(s): 0.011992001000180608
# Saída: 36 469
#
# value 469
# Stderr:
# Tempo total(s): 0.012161500000729575
# Saída: 18 364
#
# value 364
# Stderr:
# Tempo total(s): 0.011937379999835684
# Saída: 37 363
#
# value 363
# Stderr:
# Tempo total(s): 0.013889438000660448
# Saída: 20 322
#
# value 322
# Stderr:
# Tempo total(s): 0.012244171000020287
# Saída: 65 291
#
# value 291
# Stderr:
# Tempo total(s): 0.013227270000243152
# Saída: 48 421
#
# value 421
# Stderr:
# Tempo total(s): 0.012242309999237477
# Saída: 102 464
#
# value 464
# Stderr:
# Tempo total(s): 0.012200125999697775
# Saída: 11 130
#
# value 130
# Stderr:
# Tempo total(s): 0.011999946999821987
# Saída: 48 340
#
# value 340
# Stderr:
# Tempo total(s): 0.012618128000212891
# Saída: 20 86
#
# value 86
# Stderr:
# Tempo total(s): 0.011922481000510743
# Saída: 1 134
#
# value 134
# Stderr:
# Tempo total(s): 0.012283232000299904
# Saída: 56 521
#
# value 521
# Stderr:
# Tempo total(s): 0.012481623999519798
# Saída: 83 650
#
# value 650
# Stderr:
# Tempo total(s): 0.012315324999690347
# Saída: 0 0
#
# value 0
# Stderr:
# Tempo total(s): 0.012421690999872226
# Saída: 14 322
#
# value 322
# Stderr:
# Tempo total(s): 0.011894822000613203
# Saída: 57 499
#
# value 499
# Stderr:
# Tempo total(s): 0.012198385999909078
# Saída: 61 434
#
# value 434
# Stderr:
# Tempo total(s): 0.012750726999911421
# Saída: 31 200
#
# value 200
# Stderr:
# Tempo total(s): 0.013940206000370381
# Saída: 2 221
#
# value 221
# Stderr:
# Tempo total(s): 0.012094938000700495
# Saída: 115 699
#
# value 699
# Stderr:
# Tempo total(s): 0.012025560000438418
# Saída: 29 490
#
# value 490
# Stderr:
# Tempo total(s): 0.012679461000516312
# Saída: 139 1057
#
# value 1057
# Stderr:
# Tempo total(s): 0.0123413299997992
# Saída: 110 1301
#
# value 1301
# Stderr:
# Tempo total(s): 0.012060017999829142
# Saída: 24 332
#
# value 332
# Stderr:
# Tempo total(s): 0.012155664000601973
# Saída: 79 718
#
# value 718
# Stderr:
# Tempo total(s): 0.012162267999883625
# Saída: 62 858
#
# value 858
# Stderr:
# Tempo total(s): 0.012045391000356176
# Saída: 102 1066
#
# value 1066
# Stderr:
# Tempo total(s): 0.01255575899995165
# Saída: 46 450
#
# value 450
# Stderr:
# Tempo total(s): 0.012103674999707437
# Saída: 108 1131
#
# value 1131
# Stderr:
# Tempo total(s): 0.011982670999714173
# Saída: 88 957
#
# value 957
# Stderr:
# Tempo total(s): 0.011895476000063354
# Saída: 20 543
#
# value 543
# Stderr:
# Tempo total(s): 0.012349700000413577
# Saída: 74 938
#
# value 938
# Stderr:
# Tempo total(s): 0.01207956700000068
# Saída: 72 827
#
# value 827
# Stderr:
# Tempo total(s): 0.0125689019996571
# Saída: 147 1496
#
# value 1496
# Stderr:
# Tempo total(s): 0.01300784900013241
# Saída: 20 935
#
# value 935
# Stderr:
# Tempo total(s): 0.012209790999804682
# Saída: 151 1302
#
# value 1302
# Stderr:
# Tempo total(s): 0.012220444000377029
# Saída: 130 877
#
# value 877
# Stderr:
# Tempo total(s): 0.01276514499932091
# Saída: 120 1132
#
# value 1132
# Stderr:
# Tempo total(s): 0.012194541999633657
# Saída: 78 751
#
# value 751
# Stderr:
# Tempo total(s): 0.012149729999691772
# Saída: 51 654
#
# value 654
# Stderr:
# Tempo total(s): 0.012055117999807408
# Saída: 63 1032
#
# value 1032
# Stderr:
# Tempo total(s): 0.012167473999397771
# Saída: 218 1084
#
# value 1084
# Stderr:
# Tempo total(s): 0.012181305000012799
# Saída: 95 1191
#
# value 1191
# Stderr:
# Tempo total(s): 0.011978823000390548
# Saída: 46 345
#
# value 345
# Stderr:
# Tempo total(s): 0.012132943000324303
# Saída: 97 583
#
# value 583
# Stderr:
# Tempo total(s): 0.012025028999232745
# Saída: 101 1587
#
# value 1587
# Stderr:
# Tempo total(s): 0.012117061000026297
# Saída: 154 1356
#
# value 1356
# Stderr:
# Tempo total(s): 0.012080710000191175
# Saída: 72 1266
#
# value 1266
# Stderr:
# Tempo total(s): 0.012357596000583726
# Saída: 29 626
#
# value 626
# Stderr:
# Tempo total(s): 0.012126308999540925
# Saída: 71 647
#
# value 647
# Stderr:
# Tempo total(s): 0.01201936800043768
# Saída: 109 830
#
# value 830
# Stderr:
# Tempo total(s): 0.01277056300023105
# Saída: 59 1087
#
# value 1087
# Stderr:
# Tempo total(s): 0.011881452000125137
# Saída: 85 781
#
# value 781
# Stderr:
# Tempo total(s): 0.01273616700018465
# Saída: 70 1009
#
# value 1009
# Stderr:
# Tempo total(s): 0.011854108000079577
# Saída: 140 2241
#
# value 2241
# Stderr:
# Tempo total(s): 0.012370911999823875
# Saída: 141 1309
#
# value 1309
# Stderr:
# Tempo total(s): 0.0131267310007388
# Saída: 178 1034
#
# value 1034
# Stderr:
# Tempo total(s): 0.012082062999979826
# Saída: 40 522
#
# value 522
# Stderr:
# Tempo total(s): 0.011887685999681707
# Saída: 245 2486
#
# value 2486
# Stderr:
# Tempo total(s): 0.012344214999757241
# Saída: 103 1446
#
# value 1446
# Stderr:
# Tempo total(s): 0.011851561000185029
# Saída: 202 2064
#
# value 2064
# Stderr:
# Tempo total(s): 0.011819001000731078
# Saída: 122 2518
#
# value 2518
# Stderr:
# Tempo total(s): 0.01190262099953543
# Saída: 222 3934
#
# value 3934
# Stderr:
# Tempo total(s): 0.012739287999465887
# Saída: 42 781
#
# value 781
# Stderr:
# Tempo total(s): 0.012223017999531294
# Saída: 221 1018
#
# value 1018
# Stderr:
# Tempo total(s): 0.012087420000170823
# Saída: 85 1261
#
# value 1261
# Stderr:
# Tempo total(s): 0.011554626999895845
# Saída: 58 1114
#
# value 1114
# Stderr:
# Tempo total(s): 0.011566156999833765
# Saída: 52 1027
#
# value 1027
# Stderr:
# Tempo total(s): 0.011956106000070577
# Saída: 9 213
#
# value 213
# Stderr:
# Tempo total(s): 0.01190698699974746
# Saída: 237 1533
#
# value 1533
# Stderr:
# Tempo total(s): 0.012174593000054301
# Saída: 58 664
#
# value 664
# Stderr:
# Tempo total(s): 0.01145522400020127
# Saída: 134 1057
#
# value 1057
# Stderr:
# Tempo total(s): 0.011614557999564568
# Saída: 37 530
#
# value 530
# Stderr:
# Tempo total(s): 0.01232849999996688
# Saída: 5 153
#
# value 153
# Stderr:
# Tempo total(s): 0.011615608000283828
# Saída: 136 3398
#
# value 3398
# Stderr:
# Tempo total(s): 0.012457925000489922
# Saída: 164 1316
#
# value 1316
# Stderr:
# Tempo total(s): 0.012480792000133079
# Saída: 17 336
#
# value 336
# Stderr:
# Tempo total(s): 0.011824093000541325
# Saída: 149 330
#
# value 330
# Stderr:
# Tempo total(s): 0.011566850000235718
# Saída: 158 1892
#
# value 1892
# Stderr:
# Tempo total(s): 0.011877464999997756
# Saída: 155 1227
#
# value 1227
# Stderr:
# Tempo total(s): 0.012058841999532888
# Saída: 55 712
#
# value 712
# Stderr:
# Tempo total(s): 0.012337357999967935
# Saída: 302 2230
#
# value 2230
# Stderr:
# Tempo total(s): 0.011883160000252246
# Saída: 47 818
#
# value 818
# Stderr:
# Tempo total(s): 0.011857758000587637
# Saída: 126 1538
#
# value 1538
# Stderr:
# Tempo total(s): 0.01219049300016195
# Saída: 207 2591
#
# value 2591
# Stderr:
# Tempo total(s): 0.011996947000625369
# Saída: 23 509
#
# value 509
# Stderr:
# Tempo total(s): 0.01258237799993367
# Saída: 206 2278
#
# value 2278
# Stderr:
# Tempo total(s): 0.01154721199964115
# Saída: 272 1448
#
# value 1448
# Stderr:
# Tempo total(s): 0.01228058000015153
# Saída: 143 1701
#
# value 1701
# Stderr:
# Tempo total(s): 0.012603729000147723
# Saída: 92 1352
#
# value 1352
# Stderr:
# Tempo total(s): 0.011498161000417895
# Saída: 247 3769
#
# value 3769
# Stderr:
# Tempo total(s): 0.011292148000393354
# Saída: 53 730
#
# value 730
# Stderr:
# Tempo total(s): 0.011570427999686217
# Saída: 14 1347
#
# value 1347
# Stderr:
# Tempo total(s): 0.011546232999535277
# Saída: 101 830
#
# value 830
# Stderr:
# Tempo total(s): 0.011750468000172987
# Saída: 170 1772
#
# value 1772
# Stderr:
# Tempo total(s): 0.01217698999971617
# Saída: 278 1909
#
# value 1909
# Stderr:
# Tempo total(s): 0.012408957000843657
# Saída: 68 1984
#
# value 1984
# Stderr:
# Tempo total(s): 0.012111499000639014
# Saída: 91 696
#
# value 696
# Stderr:
# Tempo total(s): 0.01177896600074746
# Saída: 6 179
#
# value 179
# Stderr:
# Tempo total(s): 0.011746554999263026
# Saída: 115 1972
#
# value 1972
# Stderr:
# Tempo total(s): 0.011702132999744208
# Saída: 13 495
#
# value 495
# Stderr:
# Tempo total(s): 0.011552452000614721
# Saída: 214 1206
#
# value 1206
# Stderr:
# Tempo total(s): 0.011454800999672443
# Saída: 353 3696
#
# value 3696
# Stderr:
# Tempo total(s): 0.011851561999719706
# Saída: 273 3123
#
# value 3123
# Stderr:
# Tempo total(s): 0.011630316999799106
# Saída: 117 3332
#
# value 3332
# Stderr:
# Tempo total(s): 0.012062001999765926
# Saída: 219 1986
#
# value 1986
# Stderr:
# Tempo total(s): 0.012480807999963872
# Saída: 157 2934
#
# value 2934
# Stderr:
# Tempo total(s): 0.01172880299964163
# Saída: 232 1932
#
# value 1932
# Stderr:
# Tempo total(s): 0.012246917000084068
# Saída: 144 913
#
# value 913
# Stderr:
# Tempo total(s): 0.01177175900011207
# Saída: 49 1455
#
# value 1455
# Stderr:
# Tempo total(s): 0.011447478999798477
# Saída: 37 1491
#
# value 1491
# Stderr:
# Tempo total(s): 0.01196151599924633
# Saída: 3 368
#
# value 368
# Stderr:
# Tempo total(s): 0.011854977999973926
# Saída: 6 546
#
# value 546
# Stderr:
# Tempo total(s): 0.012327019000622386
# Saída: 132 1628
#
# value 1628
# Stderr:
# Tempo total(s): 0.011536869999872579
# Saída: 149 2540
#
# value 2540
# Stderr:
# Tempo total(s): 0.011579193999750714
# Saída: 108 3108
#
# value 3108
# Stderr:
# Tempo total(s): 0.011702273000082641
# Saída: 143 1229
#
# value 1229
# Stderr:
# Tempo total(s): 0.01164314900051977
# Saída: 92 2025
#
# value 2025
# Stderr:
# Tempo total(s): 0.012267838999832748
# Saída: 28 1784
#
# value 1784
# Stderr:
# Tempo total(s): 0.011259621000135667
# Saída: 319 3461
#
# value 3461
# Stderr:
# Tempo total(s): 0.011787706000177423
# Saída: 32 1969
#
# value 1969
# Stderr:
# Tempo total(s): 0.012213266999424377
# Saída: 108 1463
#
# value 1463
# Stderr:
# Tempo total(s): 0.011406423999687831
# Saída: 249 1844
#
# value 1844
# Stderr:
# Tempo total(s): 0.01213418699990143
# Saída: 140 3739
#
# value 3739
# Stderr:
# Tempo total(s): 0.012073118000444083
# Saída: 206 2910
#
# value 2910
# Stderr:
# Tempo total(s): 0.011852426000587002
# Saída: 39 913
#
# value 913
# Stderr:
# Tempo total(s): 0.011934207000194874
# Saída: 200 662
#
# value 662
# Stderr:
# Tempo total(s): 0.013215496000157145
# Saída: 34 306
#
# value 306
# Stderr:
# Tempo total(s): 0.01220150700009981
# Saída: 338 3121
#
# value 3121
# Stderr:
# Tempo total(s): 0.011756224000237125
# Saída: 157 1444
#
# value 1444
# Stderr:
# Tempo total(s): 0.01166297600047983
# Saída: 140 1192
#
# value 1192
# Stderr:
# Tempo total(s): 0.011974302000453463
# Saída: 145 1960
#
# value 1960
# Stderr:
# Tempo total(s): 0.011978851000094437
# Saída: 243 2971
#
# value 2971
# Stderr:
# Tempo total(s): 0.01185507799982588
# Saída: 159 1371
#
# value 1371
# Stderr:
# Tempo total(s): 0.011803245000010065
# Saída: 104 3370
#
# value 3370
# Stderr:
# Tempo total(s): 0.011755035000533098
# Saída: 274 2133
#
# value 2133
# Stderr:
# Tempo total(s): 0.012304556999879424
# Saída: 226 4517
#
# value 4517
# Stderr:
# Tempo total(s): 0.011449749999883352
# Saída: 32 2001
#
# value 2001
# Stderr:
# Tempo total(s): 0.011768384999413684
# Saída: 205 5471
#
# value 5471
# Stderr:
# Tempo total(s): 0.012143785999796819
# Saída: 62 3913
#
# value 3913
# Stderr:
# Tempo total(s): 0.011291603999779909
# Saída: 174 2481
#
# value 2481
# Stderr:
# Tempo total(s): 0.01120913699924131
# Saída: 123 1908
#
# value 1908
# Stderr:
# Tempo total(s): 0.011237708999942697
# Saída: 263 2120
#
# value 2120
# Stderr:
# Tempo total(s): 0.013982629999190976
# Saída: 498 4674
#
# value 4674
# Stderr:
# Tempo total(s): 0.013362131000576483
# Saída: 28 593
#
# value 593
# Stderr:
# Tempo total(s): 0.01254365500062704
# Saída: 135 2776
#
# value 2776
# Stderr:
# Tempo total(s): 0.011562974999833386
# Saída: 411 3220
#
# value 3220
# Stderr:
# Tempo total(s): 0.011497776999931375
# Saída: 101 3298
#
# value 3298
# Stderr:
# Tempo total(s): 0.011484888999802934
# Saída: 255 4516
#
# value 4516
# Stderr:
# Tempo total(s): 0.012370147000183351
# Saída: 166 3721
#
# value 3721
# Stderr:
# Tempo total(s): 0.01179268099986075
# Saída: 91 1674
#
# value 1674
# Stderr:
# Tempo total(s): 0.011362684999767225
# Saída: 90 1408
#
# value 1408
# Stderr:
# Tempo total(s): 0.011968683000304736
# Saída: 196 1518
#
# value 1518
# Stderr:
# Tempo total(s): 0.011667018000480311
# Saída: 314 2874
#
# value 2874
# Stderr:
# Tempo total(s): 0.012238192000040726
# Saída: 175 1286
#
# value 1286
# Stderr:
# Tempo total(s): 0.01153197499934322
# Saída: 211 3477
#
# value 3477
# Stderr:
# Tempo total(s): 0.01178511200032517
# Saída: 124 3562
#
# value 3562
# Stderr:
# Tempo total(s): 0.01329583700044168
# Saída: 427 9584
#
# value 9584
# Stderr:
# Tempo total(s): 0.011623282000073232
# Saída: 404 4413
#
# value 4413
# Stderr:
# Tempo total(s): 0.012573259000419057
# Saída: 243 3008
#
# value 3008
# Stderr:
# Tempo total(s): 0.012141187999986869
# Saída: 193 3904
#
# value 3904
# Stderr:
# Tempo total(s): 0.01217899900075281
# Saída: 41 479
#
# value 479
# Stderr:
# Tempo total(s): 0.011677423000037379
# Saída: 286 6585
#
# value 6585
# Stderr:
# Tempo total(s): 0.011531823999575863
# Saída: 235 3143
#
# value 3143
# Stderr:
# Tempo total(s): 0.011731758999303565
# Saída: 186 1687
#
# value 1687
# Stderr:
# Tempo total(s): 0.011676429000544886
# Saída: 97 4456
#
# value 4456
# Stderr:
# Tempo total(s): 0.012635153000701393
# Saída: 525 6731
#
# value 6731
# Stderr:
# Tempo total(s): 0.011675388000185194
# Saída: 113 5019
#
# value 5019
# Stderr:
# Tempo total(s): 0.012394018000122742
# Saída: 238 2852
#
# value 2852
# Stderr:
# Tempo total(s): 0.011455238999587891
# Saída: 80 1589
#
# value 1589
# Stderr:
# Tempo total(s): 0.012926315999720828
# Saída: 109 5578
#
# value 5578
# Stderr:
# Tempo total(s): 0.012806666999495064
# Saída: 214 2132
#
# value 2132
# Stderr:
# Tempo total(s): 0.011515859999235545
# Saída: 357 7440
#
# value 7440
# Stderr:
# Tempo total(s): 0.012376679999761109
# Saída: 404 5568
#
# value 5568
# Stderr:
# Tempo total(s): 0.011563007999939146
# Saída: 167 1664
#
# value 1664
# Stderr:
# Tempo total(s): 0.012432803000592685
# Saída: 339 3419
#
# value 3419
# Stderr:
# Tempo total(s): 0.011599510999985796
# Saída: 209 784
#
# value 784
# Stderr:
# Tempo total(s): 0.012453145000108634
# Saída: 93 2536
#
# value 2536
# Stderr:
# Tempo total(s): 0.011792271000558685
# Saída: 99 1620
#
# value 1620
# Stderr:
# Tempo total(s): 0.01270939499954693
# Saída: 59 1400
#
# value 1400
# Stderr:
# Tempo total(s): 0.011925515000257292
# Saída: 205 2272
#
# value 2272
# Stderr:
# Tempo total(s): 0.01165082299939968
# Saída: 476 2886
#
# value 2886
# Stderr:
# Tempo total(s): 0.01182747299935727
# Saída: 414 1293
#
# value 1293
# Stderr:
# Tempo total(s): 0.012023645999761357
# Saída: 213 3401
#
# value 3401
# Stderr:
# Tempo total(s): 0.012511023999650206
# Saída: 139 1271
#
# value 1271
# Stderr:
# Tempo total(s): 0.012182509000012942
# Saída: 45 2802
#
# value 2802
# Stderr:
# Tempo total(s): 0.012710753000646946
# Saída: 235 1531
#
# value 1531
# Stderr:
# Tempo total(s): 0.0117779120000705
# Saída: 557 4496
#
# value 4496
# Stderr:
# Tempo total(s): 0.012471522999476292
# Saída: 528 6308
#
# value 6308
# Stderr:
# Tempo total(s): 0.011599392999414704
# Saída: 457 4309
#
# value 4309
# Stderr:
# Tempo total(s): 0.01170835100037948
# Saída: 569 3294
#
# value 3294
# Stderr:
# Tempo total(s): 0.012587423000695708
# Saída: 385 6866
#
# value 6866
# Stderr:
# Tempo total(s): 0.013022721000197635
# Saída: 30 1876
#
# value 1876
# Stderr:
# Tempo total(s): 0.01305255599982047
# Saída: 218 2131
#
# value 2131
# Stderr:
# Tempo total(s): 0.011863212999742245
# Saída: 106 1814
#
# value 1814
# Stderr:
# Tempo total(s): 0.011715957999513193
# Saída: 146 3426
#
# value 3426
# Stderr:
# Tempo total(s): 0.012236932000632805
# Saída: 189 4788
#
# value 4788
# Stderr:
# Tempo total(s): 0.011793815999226354
# Saída: 372 4534
#
# value 4534
# Stderr:
# Tempo total(s): 0.012153625999417272
# Saída: 31 784
#
# value 784
# Stderr:
# Tempo total(s): 0.011835434000204259
# Saída: 569 11753
#
# value 11753
# Stderr:
# Tempo total(s): 0.012488554999436019
# Saída: 236 2155
#
# value 2155
# Stderr:
# Tempo total(s): 0.012055187000441947
# Saída: 160 1342
#
# value 1342
# Stderr:
# Tempo total(s): 0.012132412999562803
# Saída: 600 9063
#
# value 9063
# Stderr:
# Tempo total(s): 0.011955009999837785
# Saída: 316 3355
#
# value 3355
# Stderr:
# Tempo total(s): 0.011678877000122156
# Saída: 112 3051
#
# value 3051
# Stderr:
# Tempo total(s): 0.011988167000708927
# Saída: 367 9876
#
# value 9876
# Stderr:
# Tempo total(s): 0.012322492000748753
# Saída: 22 657
#
# value 657
# Stderr:
# Tempo total(s): 0.013071583000055398
# Saída: 72 1294
#
# value 1294
# Stderr:
# Tempo total(s): 0.012201728000036383
# Saída: 456 6385
#
# value 6385
# Stderr:
# Tempo total(s): 0.012186081000436388
# Saída: 122 1117
#
# value 1117
# Stderr:
# Tempo total(s): 0.011769261000154074
# Saída: 65 1684
#
# value 1684
# Stderr:
# Tempo total(s): 0.011908675999620755
# Saída: 118 1759
#
# value 1759
# Stderr:
# Tempo total(s): 0.012138342000071134
# Saída: 17 426
#
# value 426
# Stderr:
# Tempo total(s): 0.012537814999632246
# Saída: 145 2860
#
# value 2860
# Stderr:
# Tempo total(s): 0.011734038999748009
# Saída: 26 2475
#
# value 2475
# Stderr:
# Tempo total(s): 0.012089682000805624
# Saída: 351 2070
#
# value 2070
# Stderr:
# Tempo total(s): 0.013213532999543531
# Saída: 38 960
#
# value 960
# Stderr:
# Tempo total(s): 0.013422988999991503
# Saída: 261 4772
#
# value 4772
# Stderr:
# Tempo total(s): 0.01239012400037609
# Saída: 0 0
#
# value 0
# Stderr:
# Tempo total(s): 0.011890847000358917
# Saída: 513 1582
#
# value 1582
# Stderr:
# Tempo total(s): 0.01218569299999217
# Saída: 250 6826
#
# value 6826
# Stderr:
# Tempo total(s): 0.01182120900011796
# Saída: 57 1403
#
# value 1403
# Stderr:
# Tempo total(s): 0.011714756999936071
# Saída: 107 1564
#
# value 1564
# Stderr:
# Tempo total(s): 0.014130656000816089
# Saída: 202 3533
#
# value 3533
# Stderr:
# Tempo total(s): 0.012271653000425431
# Saída: 49 1673
#
# value 1673
# Stderr:
# Tempo total(s): 0.012269087000277068
# Saída: 229 3951
#
# value 3951
# Stderr:
# Tempo total(s): 0.011883273999956145
# Saída: 321 3276
#
# value 3276
# Stderr:
# Tempo total(s): 0.0117327079997267
# Saída: 173 2353
#
# value 2353
# Stderr:
# Tempo total(s): 0.012512981000327272
# Saída: 67 700
#
# value 700
# Stderr:
# Tempo total(s): 0.012937640000018291
# Saída: 213 3049
#
# value 3049
# Stderr:
# Tempo total(s): 0.012828992999857292
# Saída: 133 4947
#
# value 4947
# Stderr:
# Tempo total(s): 0.012228483000399137
# Saída: 88 4357
#
# value 4357
# Stderr:
# Tempo total(s): 0.012378610999803641
# Saída: 205 1804
#
# value 1804
# Stderr:
# Tempo total(s): 0.012626523999642814
# Saída: 27 2040
#
# value 2040
# Stderr:
# Tempo total(s): 0.012824106000152824
# Saída: 580 5976
#
# value 5976
# Stderr:
# Tempo total(s): 0.013231744999757211
# Saída: 65 2143
#
# value 2143
# Stderr:
# Tempo total(s): 0.012184279000393872
# Saída: 7 902
#
# value 902
# Stderr:
# Tempo total(s): 0.011740833999283495
# Saída: 827 6502
#
# value 6502
# Stderr:
# Tempo total(s): 0.012455760999728227
# Saída: 61 3974
#
# value 3974
# Stderr:
# Tempo total(s): 0.012515958999756549
# Saída: 212 3260
#
# value 3260
# Stderr:
# Tempo total(s): 0.012466675000723626
# Saída: 245 5422
#
# value 5422
# Stderr:
# Tempo total(s): 0.012138142999901902
# Saída: 85 4129
#
# value 4129
# Stderr:
# Tempo total(s): 0.012690612000369583
# Saída: 532 8699
#
# value 8699
# Stderr:
# Tempo total(s): 0.012097857000298973
# Saída: 93 3036
#
# value 3036
# Stderr:
# Tempo total(s): 0.012369932999718003
# Saída: 177 2931
#
# value 2931
# Stderr:
# Tempo total(s): 0.012045837999721698
# Saída: 307 5812
#
# value 5812
# Stderr:
# Tempo total(s): 0.011721905999365845
# Saída: 267 3680
#
# value 3680
# Stderr:
# Tempo total(s): 0.01184532500064961
# Saída: 123 4186
#
# value 4186
# Stderr:
# Tempo total(s): 0.012156744000094477
# Saída: 127 2036
#
# value 2036
# Stderr:
# Tempo total(s): 0.012296513999899616
# Saída: 441 9001
#
# value 9001
# Stderr:
# Tempo total(s): 0.01233213099931163
# Saída: 649 6736
#
# value 6736
# Stderr:
# Tempo total(s): 0.011969238000347104
# Saída: 194 3132
#
# value 3132
# Stderr:
# Tempo total(s): 0.01236335199973837
# Saída: 4 36
#
# value 36
# Stderr:
# Tempo total(s): 0.023224683000080404
# Saída: 6 26
#
# value 26
# Stderr:
# Tempo total(s): 0.02341554000031465
# Saída: 2 28
#
# value 28
# Stderr:
# Tempo total(s): 0.024468034000165062
# Saída: 5 11
#
# value 11
# Stderr:
# Tempo total(s): 0.02067112900022039
# Saída: 6 27
#
# value 27
# Stderr:
# Tempo total(s): 0.021425959000225703
# Saída: 2 20
#
# value 20
# Stderr:
# Tempo total(s): 0.021392833000390965
# Saída: 8 50
#
# value 50
# Stderr:
# Tempo total(s): 0.02167718500004412
# Saída: 13 83
#
# value 83
# Stderr:
# Tempo total(s): 0.02125757099929615
# Saída: 17 90
#
# value 90
# Stderr:
# Tempo total(s): 0.021996577000209072
# Saída: 4 39
#
# value 39
# Stderr:
# Tempo total(s): 0.02249578400005703
# Saída: 27 244
#
# value 244
# Stderr:
# Tempo total(s): 0.02286270400054491
# Saída: 20 148
#
# value 148
# Stderr:
# Tempo total(s): 0.022550412999407854
# Saída: 6 104
#
# value 104
# Stderr:
# Tempo total(s): 0.021883239999624493
# Saída: 26 156
#
# value 156
# Stderr:
# Tempo total(s): 0.02206267299970932
# Saída: 15 94
#
# value 94
# Stderr:
# Tempo total(s): 0.02147552499991434
# Saída: 35 381
#
# value 381
# Stderr:
# Tempo total(s): 0.022521310999763955
# Saída: 13 126
#
# value 126
# Stderr:
# Tempo total(s): 0.021923789999164
# Saída: 31 180
#
# value 180
# Stderr:
# Tempo total(s): 0.022974323999733315
# Saída: 21 221
#
# value 221
# Stderr:
# Tempo total(s): 0.02181537899923569
# Saída: 6 119
#
# value 119
# Stderr:
# Tempo total(s): 0.021840858999894408
# Saída: 50 678
#
# value 678
# Stderr:
# Tempo total(s): 0.024927161000050546
# Saída: 63 651
#
# value 651
# Stderr:
# Tempo total(s): 0.023796106999725453
# Saída: 17 168
#
# value 168
# Stderr:
# Tempo total(s): 0.025459716999648663
# Saída: 2 74
#
# value 74
# Stderr:
# Tempo total(s): 0.024372475000745908
# Saída: 56 877
#
# value 877
# Stderr:
# Tempo total(s): 0.026336992000324244
# Saída: 38 414
#
# value 414
# Stderr:
# Tempo total(s): 0.02483618199948978
# Saída: 14 318
#
# value 318
# Stderr:
# Tempo total(s): 0.025270316999922215
# Saída: 75 632
#
# value 632
# Stderr:
# Tempo total(s): 0.025824657999692135
# Saída: 29 255
#
# value 255
# Stderr:
# Tempo total(s): 0.024181884999961767
# Saída: 34 432
#
# value 432
# Stderr:
# Tempo total(s): 0.023867551999501302
# Saída: 80 843
#
# value 843
# Stderr:
# Tempo total(s): 0.02465863499946863
# Saída: 45 256
#
# value 256
# Stderr:
# Tempo total(s): 0.024578152999310987
# Saída: 18 315
#
# value 315
# Stderr:
# Tempo total(s): 0.024538065000342613
# Saída: 40 321
#
# value 321
# Stderr:
# Tempo total(s): 0.022886682999342156
# Saída: 36 321
#
# value 321
# Stderr:
# Tempo total(s): 0.023782170000231417
# Saída: 28 150
#
# value 150
# Stderr:
# Tempo total(s): 0.024733696000112104
# Saída: 19 546
#
# value 546
# Stderr:
# Tempo total(s): 0.0246190520001619
# Saída: 28 310
#
# value 310
# Stderr:
# Tempo total(s): 0.024331467999218148
# Saída: 35 634
#
# value 634
# Stderr:
# Tempo total(s): 0.02416490699943097
# Saída: 5 381
#
# value 381
# Stderr:
# Tempo total(s): 0.025265435000619618
# Saída: 36 303
#
# value 303
# Stderr:
# Tempo total(s): 0.024446637999972154
# Saída: 58 559
#
# value 559
# Stderr:
# Tempo total(s): 0.023664871000619314
# Saída: 50 678
#
# value 678
# Stderr:
# Tempo total(s): 0.024842765000357758
# Saída: 3 111
#
# value 111
# Stderr:
# Tempo total(s): 0.02648420100013027
# Saída: 36 1055
#
# value 1055
# Stderr:
# Tempo total(s): 0.025367027000356757
# Saída: 24 561
#
# value 561
# Stderr:
# Tempo total(s): 0.028647490999901493
# Saída: 33 514
#
# value 514
# Stderr:
# Tempo total(s): 0.02812031899975409
# Saída: 24 498
#
# value 498
# Stderr:
# Tempo total(s): 0.026592125999741256
# Saída: 66 643
#
# value 643
# Stderr:
# Tempo total(s): 0.026816040000085195
# Saída: 47 492
#
# value 492
# Stderr:
# Tempo total(s): 0.02596688100038591
# Saída: 99 1522
#
# value 1522
# Stderr:
# Tempo total(s): 0.026217069999802334
# Saída: 12 230
#
# value 230
# Stderr:
# Tempo total(s): 0.024977963999845088
# Saída: 49 435
#
# value 435
# Stderr:
# Tempo total(s): 0.025661849999778497
# Saída: 20 312
#
# value 312
# Stderr:
# Tempo total(s): 0.026316608000342967
# Saída: 1 134
#
# value 134
# Stderr:
# Tempo total(s): 0.028917712999827927
# Saída: 56 1389
#
# value 1389
# Stderr:
# Tempo total(s): 0.030878633999236627
# Saída: 88 670
#
# value 670
# Stderr:
# Tempo total(s): 0.029215772000497964
# Saída: 5 88
#
# value 88
# Stderr:
# Tempo total(s): 0.026147953999497986
# Saída: 15 617
#
# value 617
# Stderr:
# Tempo total(s): 0.02784132699980546
# Saída: 56 672
#
# value 672
# Stderr:
# Tempo total(s): 0.027475271000184875
# Saída: 60 1024
#
# value 1024
# Stderr:
# Tempo total(s): 0.02638992199990753
# Saída: 31 403
#
# value 403
# Stderr:
# Tempo total(s): 0.0258161800002199
# Saída: 2 221
#
# value 221
# Stderr:
# Tempo total(s): 0.027147722999870894
# Saída: 110 1027
#
# value 1027
# Stderr:
# Tempo total(s): 0.027025557999877492
# Saída: 28 1036
#
# value 1036
# Stderr:
# Tempo total(s): 0.02646236999953544
# Saída: 138 1818
#
# value 1818
# Stderr:
# Tempo total(s): 0.026005265999629046
# Saída: 115 1349
#
# value 1349
# Stderr:
# Tempo total(s): 0.02607798100052605
# Saída: 24 515
#
# value 515
# Stderr:
# Tempo total(s): 0.027704836999873805
# Saída: 78 987
#
# value 987
# Stderr:
# Tempo total(s): 0.027966797999397386
# Saída: 60 1480
#
# value 1480
# Stderr:
# Tempo total(s): 0.0272203909999007
# Saída: 108 1752
#
# value 1752
# Stderr:
# Tempo total(s): 0.026440006000484573
# Saída: 46 663
#
# value 663
# Stderr:
# Tempo total(s): 0.026747421999971266
# Saída: 108 2040
#
# value 2040
# Stderr:
# Tempo total(s): 0.027566652000132308
# ...
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# {'Tempo': 0.04307157699986419, 'Saida': 3485, 'n': 252, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.041885910000019067, 'Saida': 4416, 'n': 253, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04314057700048579, 'Saida': 8233, 'n': 254, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04102163500010647, 'Saida': 1393, 'n': 255, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04114375400058634, 'Saida': 1473, 'n': 256, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0449602610005968, 'Saida': 8780, 'n': 257, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04481979699994554, 'Saida': 3095, 'n': 258, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.041806457999882696, 'Saida': 4100, 'n': 259, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.046094475999780116, 'Saida': 3107, 'n': 260, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04541099600010057, 'Saida': 1331, 'n': 261, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0450580019996778, 'Saida': 4546, 'n': 262, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04422441200040339, 'Saida': 3316, 'n': 263, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.043998877000376524, 'Saida': 4855, 'n': 264, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04368182700000034, 'Saida': 1645, 'n': 265, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04474704499989457, 'Saida': 8249, 'n': 266, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04495393500019418, 'Saida': 896, 'n': 267, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04686660400057008, 'Saida': 7236, 'n': 268, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04552501600028336, 'Saida': 12002, 'n': 269, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04151194200039754, 'Saida': 5216, 'n': 270, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04456764600035967, 'Saida': 3595, 'n': 271, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04756460699991294, 'Saida': 5623, 'n': 272, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.05010874099934881, 'Saida': 4372, 'n': 273, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04660305900051753, 'Saida': 6655, 'n': 274, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.045793430999765405, 'Saida': 5067, 'n': 275, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04828929999985121, 'Saida': 5783, 'n': 276, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.046586033000494353, 'Saida': 3518, 'n': 277, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04619731000002503, 'Saida': 4346, 'n': 278, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04592530700028874, 'Saida': 6202, 'n': 279, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04583769399960147, 'Saida': 6487, 'n': 280, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.045370727999397786, 'Saida': 5872, 'n': 281, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.043332129000191344, 'Saida': 2624, 'n': 282, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04666314800033433, 'Saida': 7535, 'n': 283, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.045889273999819125, 'Saida': 2450, 'n': 284, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04630947099940386, 'Saida': 1418, 'n': 285, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04742156000065734, 'Saida': 12986, 'n': 286, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04753528199944412, 'Saida': 9572, 'n': 287, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04791288800061011, 'Saida': 4267, 'n': 288, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04727657600051316, 'Saida': 8217, 'n': 289, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04467503600062628, 'Saida': 4007, 'n': 290, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.046863181999469816, 'Saida': 12544, 'n': 291, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04656636499930755, 'Saida': 3527, 'n': 292, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04853979699964839, 'Saida': 4908, 'n': 293, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04728573800002778, 'Saida': 5586, 'n': 294, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04794808299993747, 'Saida': 8768, 'n': 295, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04688105000059295, 'Saida': 8482, 'n': 296, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04582796400063671, 'Saida': 3673, 'n': 297, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.04728668200004904, 'Saida': 11245, 'n': 298, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.049081533000389754, 'Saida': 13629, 'n': 299, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.048074549000375555, 'Saida': 7929, 'n': 300, 'Algoritmo': 'Busca Local'}
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)
# /tmp/ipykernel_3413/3757744298.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True)

# %%
df
# Out:
#      Saida     Tempo    n    Algoritmo
# 0       18  0.014358    5   Heuristica
# 1       12  0.013676    6   Heuristica
# 2       25  0.013486    7   Heuristica
# 3       11   0.01303    8   Heuristica
# 4       26  0.013454    9   Heuristica
# ..     ...       ...  ...          ...
# 883   8482  0.046881  296  Busca Local
# 884   3673  0.045828  297  Busca Local
# 885  11245  0.047287  298  Busca Local
# 886  13629  0.049082  299  Busca Local
# 887   7929  0.048075  300  Busca Local
#
# [888 rows x 4 columns]

# %%
algoritmos = list(df['Algoritmo'].value_counts().keys())

# %%
# for alg_ in algoritmos:

# %%
# df.plot.line(x = 'Tempo',y = 'Saida')
# plt.legend(['Algoritmo'])
# df_teste = df.loc[df['Algoritmo'] !='Busca Local']
df.pivot(index='n',columns='Algoritmo',values='Tempo').plot()
# Out:
# /home/marcelo/.local/lib/python3.8/site-packages/pandas/core/algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)
# <AxesSubplot:xlabel='n'>

# %%
# Out:
# oi
