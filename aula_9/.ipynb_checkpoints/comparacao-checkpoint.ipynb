# %%
import subprocess
import time
import pandas as pd

df = pd.DataFrame(columns=['Saida','Tempo','n','Algoritmo'])

lista_program = ['../aula_5/main','../aula_6/main','../busca_local/main']
lista_programs=[]
for i in lista_program:
        lista_=[]
        for j in range(1,797):
            f = open(f'inputs/in{j}.txt',"r")
            contents = f.read()
            f.close()
            n = contents.split()[0]
            start = time.perf_counter()
            proc = subprocess.run([i], input=contents, text=True, capture_output=True)
            end = time.perf_counter()
            print('Saída:', proc.stdout)
            print("value", proc.stdout.split()[-1])
            print('Stderr:', proc.stderr)
            print('Tempo total(s):', end - start)
            dic = {
                'Tempo':float(end-start),
                'Saida':int(proc.stdout.split()[-1]),
                'n': int(n)
            }
            lista_.append(dic)
        lista_programs.append(lista_)
for i in range(len(lista_programs)):
    for j in lista_programs[i]:
        if i == 0:
            alg = 'Heuristica'
        elif i == 1:
            alg = 'Aleatorio'
        else:
            alg = 'Busca Local'
        j['Algoritmo'] = alg
        df = df.append(j, ignore_index = True);
# Out:
# Saída: 1 10
#
# value 10
# Stderr:
# Tempo total(s): 0.15328227000281913
# Saída: 15 25
#
# value 25
# Stderr:
# Tempo total(s): 0.03996209100296255
# Saída: 5 18
#
# value 18
# Stderr:
# Tempo total(s): 0.035934959996666294
# Saída: 1 31
#
# value 31
# Stderr:
# Tempo total(s): 0.023980654004844837
# Saída: 7 42
#
# value 42
# Stderr:
# Tempo total(s): 0.018464553999365307
# Saída: 2 16
#
# value 16
# Stderr:
# Tempo total(s): 0.015447255995240994
# Saída: 10 43
#
# value 43
# Stderr:
# Tempo total(s): 0.015696189002483152
# Saída: 1 38
#
# value 38
# Stderr:
# Tempo total(s): 0.015203148999717087
# Saída: 17 106
#
# value 106
# Stderr:
# Tempo total(s): 0.014634433995524887
# Saída: 27 118
#
# value 118
# Stderr:
# Tempo total(s): 0.015478360997803975
# Saída: 32 144
#
# value 144
# Stderr:
# Tempo total(s): 0.013338869001017883
# Saída: 6 58
#
# value 58
# Stderr:
# Tempo total(s): 0.012675072997808456
# Saída: 1 30
#
# value 30
# Stderr:
# Tempo total(s): 0.012473242000851315
# Saída: 8 79
#
# value 79
# Stderr:
# Tempo total(s): 0.012064526999893133
# Saída: 3 48
#
# value 48
# Stderr:
# Tempo total(s): 0.012956867998582311
# Saída: 8 82
#
# value 82
# Stderr:
# Tempo total(s): 0.011397670001315419
# Saída: 1 29
#
# value 29
# Stderr:
# Tempo total(s): 0.011825297005998436
# Saída: 25 221
#
# value 221
# Stderr:
# Tempo total(s): 0.013761551999778021
# Saída: 17 76
#
# value 76
# Stderr:
# Tempo total(s): 0.01182824200077448
# Saída: 6 144
#
# value 144
# Stderr:
# Tempo total(s): 0.012232929999299813
# Saída: 8 63
#
# value 63
# Stderr:
# Tempo total(s): 0.012151024995546322
# Saída: 7 64
#
# value 64
# Stderr:
# Tempo total(s): 0.01209144600579748
# Saída: 18 61
#
# value 61
# Stderr:
# Tempo total(s): 0.012383970002701972
# Saída: 24 177
#
# value 177
# Stderr:
# Tempo total(s): 0.012379083003906999
# Saída: 3 21
#
# value 21
# Stderr:
# Tempo total(s): 0.012607343996933196
# Saída: 23 286
#
# value 286
# Stderr:
# Tempo total(s): 0.014151149000099394
# Saída: 14 54
#
# value 54
# Stderr:
# Tempo total(s): 0.013175652995414566
# Saída: 61 372
#
# value 372
# Stderr:
# Tempo total(s): 0.013156447996152565
# Saída: 55 301
#
# value 301
# Stderr:
# Tempo total(s): 0.012439079997420777
# Saída: 18 164
#
# value 164
# Stderr:
# Tempo total(s): 0.012606587006303016
# Saída: 17 79
#
# value 79
# Stderr:
# Tempo total(s): 0.012885137999546714
# Saída: 39 302
#
# value 302
# Stderr:
# Tempo total(s): 0.01413180000236025
# Saída: 5 8
#
# value 8
# Stderr:
# Tempo total(s): 0.011677741997118574
# Saída: 70 432
#
# value 432
# Stderr:
# Tempo total(s): 0.011234511999646202
# Saída: 65 724
#
# value 724
# Stderr:
# Tempo total(s): 0.010770180997496936
# Saída: 85 852
#
# value 852
# Stderr:
# Tempo total(s): 0.010339585001929663
# Saída: 28 230
#
# value 230
# Stderr:
# Tempo total(s): 0.010890944999118801
# Saída: 115 1293
#
# value 1293
# Stderr:
# Tempo total(s): 0.011362273995473515
# Saída: 22 136
#
# value 136
# Stderr:
# Tempo total(s): 0.01167870000062976
# Saída: 2 95
#
# value 95
# Stderr:
# Tempo total(s): 0.011353989997587632
# Saída: 23 417
#
# value 417
# Stderr:
# Tempo total(s): 0.01451274000282865
# Saída: 17 163
#
# value 163
# Stderr:
# Tempo total(s): 0.012886099000752438
# Saída: 19 113
#
# value 113
# Stderr:
# Tempo total(s): 0.012306646000070032
# Saída: 36 296
#
# value 296
# Stderr:
# Tempo total(s): 0.012057958003424574
# Saída: 53 503
#
# value 503
# Stderr:
# Tempo total(s): 0.011982087999058422
# Saída: 78 394
#
# value 394
# Stderr:
# Tempo total(s): 0.01222573799896054
# Saída: 89 1302
#
# value 1302
# Stderr:
# Tempo total(s): 0.0126549439955852
# Saída: 44 250
#
# value 250
# Stderr:
# Tempo total(s): 0.011881600003107451
# Saída: 74 327
#
# value 327
# Stderr:
# Tempo total(s): 0.012252011001692154
# Saída: 72 511
#
# value 511
# Stderr:
# Tempo total(s): 0.012306562995945569
# Saída: 10 207
#
# value 207
# Stderr:
# Tempo total(s): 0.01218078300007619
# Saída: 62 611
#
# value 611
# Stderr:
# Tempo total(s): 0.012529181003628764
# Saída: 66 162
#
# value 162
# Stderr:
# Tempo total(s): 0.012299957001232542
# Saída: 56 1047
#
# value 1047
# Stderr:
# Tempo total(s): 0.01245044800452888
# Saída: 75 1537
#
# value 1537
# Stderr:
# Tempo total(s): 0.012313585000811145
# Saída: 44 723
#
# value 723
# Stderr:
# Tempo total(s): 0.012656884005991742
# Saída: 63 463
#
# value 463
# Stderr:
# Tempo total(s): 0.012301979004405439
# Saída: 76 955
#
# value 955
# Stderr:
# Tempo total(s): 0.013721314993745182
# Saída: 90 721
#
# value 721
# Stderr:
# Tempo total(s): 0.012888940997072496
# Saída: 21 233
#
# value 233
# Stderr:
# Tempo total(s): 0.012844422999478411
# Saída: 42 303
#
# value 303
# Stderr:
# Tempo total(s): 0.012886044001788832
# Saída: 13 447
#
# value 447
# Stderr:
# Tempo total(s): 0.012743366998620331
# Saída: 4 166
#
# value 166
# Stderr:
# Tempo total(s): 0.011867937006172724
# Saída: 77 1867
#
# value 1867
# Stderr:
# Tempo total(s): 0.01195190400176216
# Saída: 4 130
#
# value 130
# Stderr:
# Tempo total(s): 0.01221351000276627
# Saída: 74 257
#
# value 257
# Stderr:
# Tempo total(s): 0.013723885000217706
# Saída: 43 768
#
# value 768
# Stderr:
# Tempo total(s): 0.01232936700398568
# Saída: 157 2410
#
# value 2410
# Stderr:
# Tempo total(s): 0.01232218600489432
# Saída: 53 596
#
# value 596
# Stderr:
# Tempo total(s): 0.012693162003415637
# Saída: 66 1423
#
# value 1423
# Stderr:
# Tempo total(s): 0.012434737000148743
# Saída: 172 897
#
# value 897
# Stderr:
# Tempo total(s): 0.012624924995179754
# Saída: 68 534
#
# value 534
# Stderr:
# Tempo total(s): 0.012356261002423707
# Saída: 59 1310
#
# value 1310
# Stderr:
# Tempo total(s): 0.012823655997635797
# Saída: 7 245
#
# value 245
# Stderr:
# Tempo total(s): 0.012776741001289338
# Saída: 24 632
#
# value 632
# Stderr:
# Tempo total(s): 0.013022198996623047
# Saída: 157 1692
#
# value 1692
# Stderr:
# Tempo total(s): 0.012515957998402882
# Saída: 6 375
#
# value 375
# Stderr:
# Tempo total(s): 0.013289623995660804
# Saída: 113 1420
#
# value 1420
# Stderr:
# Tempo total(s): 0.013020901998970658
# Saída: 54 1018
#
# value 1018
# Stderr:
# Tempo total(s): 0.0133787550003035
# Saída: 50 508
#
# value 508
# Stderr:
# Tempo total(s): 0.01300034399901051
# Saída: 183 1493
#
# value 1493
# Stderr:
# Tempo total(s): 0.012650747994484846
# Saída: 103 1202
#
# value 1202
# Stderr:
# Tempo total(s): 0.01263090199790895
# Saída: 195 1142
#
# value 1142
# Stderr:
# Tempo total(s): 0.01298261900228681
# Saída: 207 1088
#
# value 1088
# Stderr:
# Tempo total(s): 0.01347099400300067
# Saída: 154 1615
#
# value 1615
# Stderr:
# Tempo total(s): 0.015044956999190617
# Saída: 44 571
#
# value 571
# Stderr:
# Tempo total(s): 0.013507301999197807
# Saída: 35 517
#
# value 517
# Stderr:
# Tempo total(s): 0.013299883001309354
# Saída: 240 2766
#
# value 2766
# Stderr:
# Tempo total(s): 0.014478789002168924
# Saída: 52 709
#
# value 709
# Stderr:
# Tempo total(s): 0.014844959005131386
# Saída: 24 350
#
# value 350
# Stderr:
# Tempo total(s): 0.012443938001524657
# Saída: 72 733
#
# value 733
# Stderr:
# Tempo total(s): 0.011723139999958221
# Saída: 185 2393
#
# value 2393
# Stderr:
# Tempo total(s): 0.012816075002774596
# Saída: 41 1118
#
# value 1118
# Stderr:
# Tempo total(s): 0.013923147998866625
# Saída: 163 942
#
# value 942
# Stderr:
# Tempo total(s): 0.013733004998357501
# Saída: 61 1741
#
# value 1741
# Stderr:
# Tempo total(s): 0.01281767500040587
# Saída: 156 1598
#
# value 1598
# Stderr:
# Tempo total(s): 0.013385233003646135
# Saída: 87 1234
#
# value 1234
# Stderr:
# Tempo total(s): 0.012720168000669219
# Saída: 17 434
#
# value 434
# Stderr:
# Tempo total(s): 0.013087977000395767
# Saída: 90 761
#
# value 761
# Stderr:
# Tempo total(s): 0.013049073997535743
# Saída: 156 2439
#
# value 2439
# Stderr:
# Tempo total(s): 0.014554198998666834
# Saída: 18 287
#
# value 287
# Stderr:
# Tempo total(s): 0.0134538979982608
# Saída: 128 297
#
# value 297
# Stderr:
# Tempo total(s): 0.012186829000711441
# Saída: 22 790
#
# value 790
# Stderr:
# Tempo total(s): 0.012985430999833625
# Saída: 34 421
#
# value 421
# Stderr:
# Tempo total(s): 0.011600160993111786
# Saída: 101 787
#
# value 787
# Stderr:
# Tempo total(s): 0.011720512004103512
# Saída: 106 1166
#
# value 1166
# Stderr:
# Tempo total(s): 0.011959356001170818
# Saída: 33 920
#
# value 920
# Stderr:
# Tempo total(s): 0.01161913500254741
# Saída: 60 578
#
# value 578
# Stderr:
# Tempo total(s): 0.011573320000024978
# Saída: 137 1495
#
# value 1495
# Stderr:
# Tempo total(s): 0.01272503399377456
# Saída: 113 1836
#
# value 1836
# Stderr:
# Tempo total(s): 0.011975673005508725
# Saída: 39 906
#
# value 906
# Stderr:
# Tempo total(s): 0.012095916004909668
# Saída: 127 1372
#
# value 1372
# Stderr:
# Tempo total(s): 0.012638350002816878
# Saída: 254 1587
#
# value 1587
# Stderr:
# Tempo total(s): 0.01315973000600934
# Saída: 12 542
#
# value 542
# Stderr:
# Tempo total(s): 0.012683770997682586
# Saída: 121 472
#
# value 472
# Stderr:
# Tempo total(s): 0.012789120999514125
# Saída: 81 935
#
# value 935
# Stderr:
# Tempo total(s): 0.01247655999759445
# Saída: 8 515
#
# value 515
# Stderr:
# Tempo total(s): 0.0132291520058061
# Saída: 91 1107
#
# value 1107
# Stderr:
# Tempo total(s): 0.013627440996060614
# Saída: 187 1477
#
# value 1477
# Stderr:
# Tempo total(s): 0.01302748199668713
# Saída: 67 1964
#
# value 1964
# Stderr:
# Tempo total(s): 0.01392623800347792
# Saída: 118 1330
#
# value 1330
# Stderr:
# Tempo total(s): 0.013236982995294966
# Saída: 109 2031
#
# value 2031
# Stderr:
# Tempo total(s): 0.012556538000353612
# Saída: 75 1001
#
# value 1001
# Stderr:
# Tempo total(s): 0.012962198001332581
# Saída: 301 2545
#
# value 2545
# Stderr:
# Tempo total(s): 0.0131691129936371
# Saída: 126 1631
#
# value 1631
# Stderr:
# Tempo total(s): 0.013452327002596576
# Saída: 160 3132
#
# value 3132
# Stderr:
# Tempo total(s): 0.013502651003364008
# Saída: 8 233
#
# value 233
# Stderr:
# Tempo total(s): 0.014180673999362625
# Saída: 30 644
#
# value 644
# Stderr:
# Tempo total(s): 0.01342080000176793
# Saída: 44 323
#
# value 323
# Stderr:
# Tempo total(s): 0.012919143002363853
# Saída: 223 2707
#
# value 2707
# Stderr:
# Tempo total(s): 0.013000639999518171
# Saída: 184 2193
#
# value 2193
# Stderr:
# Tempo total(s): 0.01280401399708353
# Saída: 151 3253
#
# value 3253
# Stderr:
# Tempo total(s): 0.01298967999900924
# Saída: 90 309
#
# value 309
# Stderr:
# Tempo total(s): 0.012690527997619938
# Saída: 88 1620
#
# value 1620
# Stderr:
# Tempo total(s): 0.012525766003818717
# Saída: 131 1775
#
# value 1775
# Stderr:
# Tempo total(s): 0.013270924995595124
# Saída: 29 760
#
# value 760
# Stderr:
# Tempo total(s): 0.014480190999165643
# Saída: 10 716
#
# value 716
# Stderr:
# Tempo total(s): 0.012717582998448052
# Saída: 195 1271
#
# value 1271
# Stderr:
# Tempo total(s): 0.013154303000192158
# Saída: 48 2479
#
# value 2479
# Stderr:
# Tempo total(s): 0.012073096993844956
# Saída: 28 350
#
# value 350
# Stderr:
# Tempo total(s): 0.011186794996319804
# Saída: 66 483
#
# value 483
# Stderr:
# Tempo total(s): 0.011661608004942536
# Saída: 199 1347
#
# value 1347
# Stderr:
# Tempo total(s): 0.011561399995116517
# Saída: 4 538
#
# value 538
# Stderr:
# Tempo total(s): 0.012069103999237996
# Saída: 31 1846
#
# value 1846
# Stderr:
# Tempo total(s): 0.01195576500322204
# Saída: 56 1819
#
# value 1819
# Stderr:
# Tempo total(s): 0.0129629599978216
# Saída: 222 2422
#
# value 2422
# Stderr:
# Tempo total(s): 0.012206245999550447
# Saída: 68 606
#
# value 606
# Stderr:
# Tempo total(s): 0.01184868199925404
# Saída: 155 1221
#
# value 1221
# Stderr:
# Tempo total(s): 0.011938314004510175
# Saída: 66 556
#
# value 556
# Stderr:
# Tempo total(s): 0.012280550996365491
# Saída: 90 2402
#
# value 2402
# Stderr:
# Tempo total(s): 0.012033655999402981
# Saída: 80 1304
#
# value 1304
# Stderr:
# Tempo total(s): 0.012676534002821427
# Saída: 220 4093
#
# value 4093
# Stderr:
# Tempo total(s): 0.012062114001309965
# Saída: 181 2096
#
# value 2096
# Stderr:
# Tempo total(s): 0.01206025099963881
# Saída: 82 1469
#
# value 1469
# Stderr:
# Tempo total(s): 0.012051685000187717
# Saída: 140 756
#
# value 756
# Stderr:
# Tempo total(s): 0.012034006002068054
# Saída: 239 2321
#
# value 2321
# Stderr:
# Tempo total(s): 0.012121412000851706
# Saída: 16 750
#
# value 750
# Stderr:
# Tempo total(s): 0.011868535002577119
# Saída: 187 1396
#
# value 1396
# Stderr:
# Tempo total(s): 0.012023652998323087
# Saída: 189 2096
#
# value 2096
# Stderr:
# Tempo total(s): 0.012236656002642121
# Saída: 86 973
#
# value 973
# Stderr:
# Tempo total(s): 0.013022068997088354
# Saída: 68 2074
#
# value 2074
# Stderr:
# Tempo total(s): 0.011831175004772376
# Saída: 269 3598
#
# value 3598
# Stderr:
# Tempo total(s): 0.011848013004055247
# Saída: 180 3103
#
# value 3103
# Stderr:
# Tempo total(s): 0.012008474994217977
# Saída: 272 2711
#
# value 2711
# Stderr:
# Tempo total(s): 0.011778478998166975
# Saída: 199 3632
#
# value 3632
# Stderr:
# Tempo total(s): 0.012533080000139307
# Saída: 223 2001
#
# value 2001
# Stderr:
# Tempo total(s): 0.013197546002629679
# Saída: 442 3973
#
# value 3973
# Stderr:
# Tempo total(s): 0.012659608000831213
# Saída: 265 1184
#
# value 1184
# Stderr:
# Tempo total(s): 0.013283059997775126
# Saída: 443 4546
#
# value 4546
# Stderr:
# Tempo total(s): 0.012286429002415389
# Saída: 237 2852
#
# value 2852
# Stderr:
# Tempo total(s): 0.011576944998523686
# Saída: 366 2958
#
# value 2958
# Stderr:
# Tempo total(s): 0.011840229999506846
# Saída: 140 590
#
# value 590
# Stderr:
# Tempo total(s): 0.011794035002822056
# Saída: 212 3346
#
# value 3346
# Stderr:
# Tempo total(s): 0.01286724900273839
# Saída: 147 1440
#
# value 1440
# Stderr:
# Tempo total(s): 0.012347055999271106
# Saída: 85 2808
#
# value 2808
# Stderr:
# Tempo total(s): 0.012114280005334876
# Saída: 40 709
#
# value 709
# Stderr:
# Tempo total(s): 0.012804622994735837
# Saída: 155 1141
#
# value 1141
# Stderr:
# Tempo total(s): 0.012808512998162769
# Saída: 16 1341
#
# value 1341
# Stderr:
# Tempo total(s): 0.012862887000665069
# Saída: 449 4878
#
# value 4878
# Stderr:
# Tempo total(s): 0.012331997997534927
# Saída: 338 4836
#
# value 4836
# Stderr:
# Tempo total(s): 0.012359336004010402
# Saída: 51 1130
#
# value 1130
# Stderr:
# Tempo total(s): 0.012093699995602947
# Saída: 82 1527
#
# value 1527
# Stderr:
# Tempo total(s): 0.01197112199588446
# Saída: 426 4775
#
# value 4775
# Stderr:
# Tempo total(s): 0.011960645002545789
# Saída: 286 1985
#
# value 1985
# Stderr:
# Tempo total(s): 0.011829331000626553
# Saída: 15 723
#
# value 723
# Stderr:
# Tempo total(s): 0.012194866998470388
# Saída: 50 3165
#
# value 3165
# Stderr:
# Tempo total(s): 0.012454600997443777
# Saída: 326 6122
#
# value 6122
# Stderr:
# Tempo total(s): 0.011695301000145264
# Saída: 207 4842
#
# value 4842
# Stderr:
# Tempo total(s): 0.011535514997376595
# Saída: 202 3247
#
# value 3247
# Stderr:
# Tempo total(s): 0.014495073999569286
# Saída: 175 1858
#
# value 1858
# Stderr:
# Tempo total(s): 0.011724272000719793
# Saída: 85 2256
#
# value 2256
# Stderr:
# Tempo total(s): 0.01191860899416497
# Saída: 195 550
#
# value 550
# Stderr:
# Tempo total(s): 0.01191321400256129
# Saída: 85 1288
#
# value 1288
# Stderr:
# Tempo total(s): 0.012236496004334185
# Saída: 75 1963
#
# value 1963
# Stderr:
# Tempo total(s): 0.012024308998661581
# Saída: 8 606
#
# value 606
# Stderr:
# Tempo total(s): 0.011820495004940312
# Saída: 56 2755
#
# value 2755
# Stderr:
# Tempo total(s): 0.012827761995140463
# Saída: 549 3636
#
# value 3636
# Stderr:
# Tempo total(s): 0.011958527997194324
# Saída: 110 991
#
# value 991
# Stderr:
# Tempo total(s): 0.011819859006209299
# Saída: 317 2751
#
# value 2751
# Stderr:
# Tempo total(s): 0.011881370999617502
# Saída: 515 7296
#
# value 7296
# Stderr:
# Tempo total(s): 0.011833689000923187
# Saída: 275 3839
#
# value 3839
# Stderr:
# Tempo total(s): 0.01183429200318642
# Saída: 181 4106
#
# value 4106
# Stderr:
# Tempo total(s): 0.011753589002182707
# Saída: 198 1201
#
# value 1201
# Stderr:
# Tempo total(s): 0.012875228996563237
# Saída: 366 4350
#
# value 4350
# Stderr:
# Tempo total(s): 0.012789177002559882
# Saída: 473 5018
#
# value 5018
# Stderr:
# Tempo total(s): 0.012039631001243833
# Saída: 64 1454
#
# value 1454
# Stderr:
# Tempo total(s): 0.012375633006740827
# Saída: 126 2052
#
# value 2052
# Stderr:
# Tempo total(s): 0.012080052998499013
# Saída: 164 4515
#
# value 4515
# Stderr:
# Tempo total(s): 0.012141361003159545
# Saída: 235 3347
#
# value 3347
# Stderr:
# Tempo total(s): 0.013123279997671489
# Saída: 127 1665
#
# value 1665
# Stderr:
# Tempo total(s): 0.012516424001660198
# Saída: 260 3659
#
# value 3659
# Stderr:
# Tempo total(s): 0.012155322001490276
# Saída: 29 2682
#
# value 2682
# Stderr:
# Tempo total(s): 0.01322333500138484
# Saída: 244 3965
#
# value 3965
# Stderr:
# Tempo total(s): 0.012955925994901918
# Saída: 139 1335
#
# value 1335
# Stderr:
# Tempo total(s): 0.013786641000478994
# Saída: 327 4037
#
# value 4037
# Stderr:
# Tempo total(s): 0.014096668994170614
# Saída: 145 1923
#
# value 1923
# Stderr:
# Tempo total(s): 0.011906885003554635
# Saída: 12 386
#
# value 386
# Stderr:
# Tempo total(s): 0.013721278002776671
# Saída: 57 1178
#
# value 1178
# Stderr:
# Tempo total(s): 0.012420936000125948
# Saída: 189 2303
#
# value 2303
# Stderr:
# Tempo total(s): 0.012279403003049083
# Saída: 402 3173
#
# value 3173
# Stderr:
# Tempo total(s): 0.011410197999794036
# Saída: 1 79
#
# value 79
# Stderr:
# Tempo total(s): 0.011354023998137563
# Saída: 181 2732
#
# value 2732
# Stderr:
# Tempo total(s): 0.01194215700525092
# Saída: 98 2593
#
# value 2593
# Stderr:
# Tempo total(s): 0.01212152299558511
# Saída: 43 1488
#
# value 1488
# Stderr:
# Tempo total(s): 0.012223297999298666
# Saída: 190 4156
#
# value 4156
# Stderr:
# Tempo total(s): 0.01188173300033668
# Saída: 35 1044
#
# value 1044
# Stderr:
# Tempo total(s): 0.012911399004224222
# Saída: 535 4290
#
# value 4290
# Stderr:
# Tempo total(s): 0.012453857998480089
# Saída: 81 1979
#
# value 1979
# Stderr:
# Tempo total(s): 0.012447979002899956
# Saída: 197 3481
#
# value 3481
# Stderr:
# Tempo total(s): 0.012364371999865398
# Saída: 264 5606
#
# value 5606
# Stderr:
# Tempo total(s): 0.012353222999081481
# Saída: 43 644
#
# value 644
# Stderr:
# Tempo total(s): 0.012682840999332257
# Saída: 159 1587
#
# value 1587
# Stderr:
# Tempo total(s): 0.012351763994956855
# Saída: 50 3230
#
# value 3230
# Stderr:
# Tempo total(s): 0.01276373600558145
# Saída: 195 7115
#
# value 7115
# Stderr:
# Tempo total(s): 0.012834578003094066
# Saída: 36 1485
#
# value 1485
# Stderr:
# Tempo total(s): 0.012545169003715273
# Saída: 489 8501
#
# value 8501
# Stderr:
# Tempo total(s): 0.013093896995997056
# Saída: 146 1649
#
# value 1649
# Stderr:
# Tempo total(s): 0.013479318004101515
# Saída: 236 2422
#
# value 2422
# Stderr:
# Tempo total(s): 0.013543458000640385
# Saída: 322 4426
#
# value 4426
# Stderr:
# Tempo total(s): 0.013303547995747067
# Saída: 146 1656
#
# value 1656
# Stderr:
# Tempo total(s): 0.014060611996683292
# Saída: 502 7318
#
# value 7318
# Stderr:
# Tempo total(s): 0.013641864999954123
# Saída: 155 2109
#
# value 2109
# Stderr:
# Tempo total(s): 0.014133381999272387
# Saída: 202 3344
#
# value 3344
# Stderr:
# Tempo total(s): 0.0134276079988922
# Saída: 439 7140
#
# value 7140
# Stderr:
# Tempo total(s): 0.013162579001800623
# Saída: 218 3807
#
# value 3807
# Stderr:
# Tempo total(s): 0.012971382995601743
# Saída: 541 6594
#
# value 6594
# Stderr:
# Tempo total(s): 0.012921128996822517
# Saída: 15 1366
#
# value 1366
# Stderr:
# Tempo total(s): 0.013501909001206513
# Saída: 254 3379
#
# value 3379
# Stderr:
# Tempo total(s): 0.013518920000933576
# Saída: 110 2373
#
# value 2373
# Stderr:
# Tempo total(s): 0.014136336998490151
# Saída: 188 5627
#
# value 5627
# Stderr:
# Tempo total(s): 0.013755353997112252
# Saída: 135 4564
#
# value 4564
# Stderr:
# Tempo total(s): 0.015540150001470465
# Saída: 184 1660
#
# value 1660
# Stderr:
# Tempo total(s): 0.013201752997701988
# Saída: 400 2334
#
# value 2334
# Stderr:
# Tempo total(s): 0.01392753999971319
# Saída: 398 4678
#
# value 4678
# Stderr:
# Tempo total(s): 0.015469780002604239
# Saída: 308 3891
#
# value 3891
# Stderr:
# Tempo total(s): 0.01313927899900591
# Saída: 70 2193
#
# value 2193
# Stderr:
# Tempo total(s): 0.012896166001155507
# Saída: 259 6073
#
# value 6073
# Stderr:
# Tempo total(s): 0.012214402995596174
# Saída: 325 2802
#
# value 2802
# Stderr:
# Tempo total(s): 0.013357044001168106
# Saída: 262 8169
#
# value 8169
# Stderr:
# Tempo total(s): 0.0128713570011314
# Saída: 296 5549
#
# value 5549
# Stderr:
# Tempo total(s): 0.012868129000707995
# Saída: 357 4975
#
# value 4975
# Stderr:
# Tempo total(s): 0.01370132799638668
# Saída: 320 2734
#
# value 2734
# Stderr:
# Tempo total(s): 0.0140512360012508
# Saída: 94 2133
#
# value 2133
# Stderr:
# Tempo total(s): 0.013239754996902775
# Saída: 344 4058
#
# value 4058
# Stderr:
# Tempo total(s): 0.012570439001137856
# Saída: 142 2091
#
# value 2091
# Stderr:
# Tempo total(s): 0.012541957999928854
# Saída: 111 1665
#
# value 1665
# Stderr:
# Tempo total(s): 0.012654389996896498
# Saída: 33 1832
#
# value 1832
# Stderr:
# Tempo total(s): 0.012730889000522438
# Saída: 327 4050
#
# value 4050
# Stderr:
# Tempo total(s): 0.013307481996889692
# Saída: 245 4186
#
# value 4186
# Stderr:
# Tempo total(s): 0.012745726002322044
# Saída: 58 2295
#
# value 2295
# Stderr:
# Tempo total(s): 0.013275263001560234
# Saída: 179 5257
#
# value 5257
# Stderr:
# Tempo total(s): 0.012494184004026465
# Saída: 450 4335
#
# value 4335
# Stderr:
# Tempo total(s): 0.012384308000036981
# Saída: 297 5406
#
# value 5406
# Stderr:
# Tempo total(s): 0.012422446001437493
# Saída: 10 3846
#
# value 3846
# Stderr:
# Tempo total(s): 0.013119010000082199
# Saída: 608 6885
#
# value 6885
# Stderr:
# Tempo total(s): 0.012707704998319969
# Saída: 111 4160
#
# value 4160
# Stderr:
# Tempo total(s): 0.013005754000914749
# Saída: 234 5767
#
# value 5767
# Stderr:
# Tempo total(s): 0.012530261999927461
# Saída: 164 2591
#
# value 2591
# Stderr:
# Tempo total(s): 0.012063689006026834
# Saída: 356 8719
#
# value 8719
# Stderr:
# Tempo total(s): 0.013027177999902051
# Saída: 462 8244
#
# value 8244
# Stderr:
# Tempo total(s): 0.011977399000898004
# Saída: 279 6413
#
# value 6413
# Stderr:
# Tempo total(s): 0.012593963998369873
# Saída: 386 2347
#
# value 2347
# Stderr:
# Tempo total(s): 0.01182299799984321
# Saída: 362 9068
#
# value 9068
# Stderr:
# Tempo total(s): 0.011670448999211658
# Saída: 329 5219
#
# value 5219
# Stderr:
# Tempo total(s): 0.012206941995827947
# Saída: 4 396
#
# value 396
# Stderr:
# Tempo total(s): 0.011819357001513708
# Saída: 322 4240
#
# value 4240
# Stderr:
# Tempo total(s): 0.011598354998568539
# Saída: 10 1167
#
# value 1167
# Stderr:
# Tempo total(s): 0.014485616004094481
# Saída: 225 6181
#
# value 6181
# Stderr:
# Tempo total(s): 0.01255527300236281
# Saída: 44 3230
#
# value 3230
# Stderr:
# Tempo total(s): 0.012348881995421834
# Saída: 206 3442
#
# value 3442
# Stderr:
# Tempo total(s): 0.01320797099469928
# Saída: 391 4947
#
# value 4947
# Stderr:
# Tempo total(s): 0.0136803540008259
# Saída: 192 1984
#
# value 1984
# Stderr:
# Tempo total(s): 0.012490376000641845
# Saída: 148 2795
#
# value 2795
# Stderr:
# Tempo total(s): 0.0134625339997001
# Saída: 340 5587
#
# value 5587
# Stderr:
# Tempo total(s): 0.01183462100016186
# Saída: 104 3847
#
# value 3847
# Stderr:
# Tempo total(s): 0.012275321998458821
# Saída: 268 4481
#
# value 4481
# Stderr:
# Tempo total(s): 0.012118724000174552
# Saída: 570 9676
#
# value 9676
# Stderr:
# Tempo total(s): 0.012445694002963137
# Saída: 124 4716
#
# value 4716
# Stderr:
# Tempo total(s): 0.012413099000696093
# Saída: 199 2133
#
# value 2133
# Stderr:
# Tempo total(s): 0.01230864399985876
# Saída: 255 4922
#
# value 4922
# Stderr:
# Tempo total(s): 0.013009875001444016
# Saída: 296 3074
#
# value 3074
# Stderr:
# Tempo total(s): 0.012102032997063361
# Saída: 218 2040
#
# value 2040
# Stderr:
# Tempo total(s): 0.011508423995110206
# Saída: 4 263
#
# value 263
# Stderr:
# Tempo total(s): 0.011681035000947304
# Saída: 273 2333
#
# value 2333
# Stderr:
# Tempo total(s): 0.01267386299878126
# Saída: 164 1905
#
# value 1905
# Stderr:
# Tempo total(s): 0.01199723099853145
# Saída: 233 6017
#
# value 6017
# Stderr:
# Tempo total(s): 0.011522694003360812
# Saída: 104 2011
#
# value 2011
# Stderr:
# Tempo total(s): 0.012331557001743931
# Saída: 593 9171
#
# value 9171
# Stderr:
# Tempo total(s): 0.012242614000570029
# Saída: 559 5947
#
# value 5947
# Stderr:
# Tempo total(s): 0.01214024200453423
# Saída: 292 2558
#
# value 2558
# Stderr:
# Tempo total(s): 0.01272726799652446
# Saída: 106 1763
#
# value 1763
# Stderr:
# Tempo total(s): 0.012659189000260085
# Saída: 11 1264
#
# value 1264
# Stderr:
# Tempo total(s): 0.011606919004407246
# Saída: 346 12161
#
# value 12161
# Stderr:
# Tempo total(s): 0.012385739995806944
# Saída: 3 514
#
# value 514
# Stderr:
# Tempo total(s): 0.012161144994024653
# Saída: 258 2803
#
# value 2803
# Stderr:
# Tempo total(s): 0.011782740002672654
# Saída: 641 8336
#
# value 8336
# Stderr:
# Tempo total(s): 0.012433091003913432
# Saída: 547 8417
#
# value 8417
# Stderr:
# Tempo total(s): 0.01229190199956065
# Saída: 413 8810
#
# value 8810
# Stderr:
# Tempo total(s): 0.012206453997350764
# Saída: 140 1101
#
# value 1101
# Stderr:
# Tempo total(s): 0.012373754994769115
# Saída: 138 2954
#
# value 2954
# Stderr:
# Tempo total(s): 0.01276104900171049
# Saída: 617 5519
#
# value 5519
# Stderr:
# Tempo total(s): 0.013704871998925228
# Saída: 31 3098
#
# value 3098
# Stderr:
# Tempo total(s): 0.013646084000356495
# Saída: 529 4692
#
# value 4692
# Stderr:
# Tempo total(s): 0.013721367999096401
# Saída: 459 5452
#
# value 5452
# Stderr:
# Tempo total(s): 0.012138436999521218
# Saída: 102 5062
#
# value 5062
# Stderr:
# Tempo total(s): 0.011914233000425156
# Saída: 124 1436
#
# value 1436
# Stderr:
# Tempo total(s): 0.011785654001869261
# Saída: 192 1734
#
# value 1734
# Stderr:
# Tempo total(s): 0.01291171699995175
# Saída: 510 5892
#
# value 5892
# Stderr:
# Tempo total(s): 0.011952541004575323
# Saída: 612 4372
#
# value 4372
# Stderr:
# Tempo total(s): 0.013072859001113102
# Saída: 763 15898
#
# value 15898
# Stderr:
# Tempo total(s): 0.012720896003884263
# Saída: 37 2173
#
# value 2173
# Stderr:
# Tempo total(s): 0.013770510005997494
# Saída: 205 7318
#
# value 7318
# Stderr:
# Tempo total(s): 0.015377353003714234
# Saída: 103 1931
#
# value 1931
# Stderr:
# Tempo total(s): 0.01357721199747175
# Saída: 47 2717
#
# value 2717
# Stderr:
# Tempo total(s): 0.014302939998742659
# Saída: 27 2567
#
# value 2567
# Stderr:
# Tempo total(s): 0.016786380001576617
# Saída: 285 8598
#
# value 8598
# Stderr:
# Tempo total(s): 0.01600002800114453
# Saída: 164 2116
#
# value 2116
# Stderr:
# Tempo total(s): 0.013865885004634038
# Saída: 55 851
#
# value 851
# Stderr:
# Tempo total(s): 0.012479696000809781
# Saída: 847 6986
#
# value 6986
# Stderr:
# Tempo total(s): 0.01213904900214402
# Saída: 149 6830
#
# value 6830
# Stderr:
# Tempo total(s): 0.012331796999205835
# Saída: 407 7822
#
# value 7822
# Stderr:
# Tempo total(s): 0.012911351004731841
# Saída: 394 5346
#
# value 5346
# Stderr:
# Tempo total(s): 0.013736993001657538
# Saída: 459 7440
#
# value 7440
# Stderr:
# Tempo total(s): 0.013316215998202097
# Saída: 509 11261
#
# value 11261
# Stderr:
# Tempo total(s): 0.013446518001728691
# Saída: 15 1453
#
# value 1453
# Stderr:
# Tempo total(s): 0.012031523998302873
# Saída: 432 10046
#
# value 10046
# Stderr:
# Tempo total(s): 0.01224158799595898
# Saída: 777 11679
#
# value 11679
# Stderr:
# Tempo total(s): 0.011393123000743799
# Saída: 46 691
#
# value 691
# Stderr:
# Tempo total(s): 0.012634165002964437
# Saída: 529 15351
#
# value 15351
# Stderr:
# Tempo total(s): 0.011415884000598453
# Saída: 358 10357
#
# value 10357
# Stderr:
# Tempo total(s): 0.01132981800037669
# Saída: 502 4338
#
# value 4338
# Stderr:
# Tempo total(s): 0.011940410004172008
# Saída: 420 4633
#
# value 4633
# Stderr:
# Tempo total(s): 0.01435586900333874
# Saída: 276 4690
#
# value 4690
# Stderr:
# Tempo total(s): 0.013395656998909544
# Saída: 728 5813
#
# value 5813
# Stderr:
# Tempo total(s): 0.011791621996962931
# Saída: 430 7777
#
# value 7777
# Stderr:
# Tempo total(s): 0.012202398000226822
# Saída: 567 7950
#
# value 7950
# Stderr:
# Tempo total(s): 0.011848381996969692
# Saída: 828 12082
#
# value 12082
# Stderr:
# Tempo total(s): 0.011745797004550695
# Saída: 434 2859
#
# value 2859
# Stderr:
# Tempo total(s): 0.011687817001075018
# Saída: 510 11234
#
# value 11234
# Stderr:
# Tempo total(s): 0.012124494001909625
# Saída: 676 11327
#
# value 11327
# Stderr:
# Tempo total(s): 0.012156778000644408
# Saída: 48 2181
#
# value 2181
# Stderr:
# Tempo total(s): 0.011924369995540474
# Saída: 674 7521
#
# value 7521
# Stderr:
# Tempo total(s): 0.012364295005681925
# Saída: 652 6374
#
# value 6374
# Stderr:
# Tempo total(s): 0.012626830000954214
# Saída: 196 4675
#
# value 4675
# Stderr:
# Tempo total(s): 0.014755447999050375
# Saída: 430 8624
#
# value 8624
# Stderr:
# Tempo total(s): 0.013517863000743091
# Saída: 927 14134
#
# value 14134
# Stderr:
# Tempo total(s): 0.015412710003147367
# Saída: 341 2521
#
# value 2521
# Stderr:
# Tempo total(s): 0.018022430005657952
# Saída: 3 480
#
# value 480
# Stderr:
# Tempo total(s): 0.013718498004891444
# Saída: 411 6283
#
# value 6283
# Stderr:
# Tempo total(s): 0.013025872998696286
# Saída: 496 3470
#
# value 3470
# Stderr:
# Tempo total(s): 0.012900360001367517
# Saída: 140 8561
#
# value 8561
# Stderr:
# Tempo total(s): 0.012086020004062448
# Saída: 489 6155
#
# value 6155
# Stderr:
# Tempo total(s): 0.01146478799637407
# Saída: 528 5892
#
# value 5892
# Stderr:
# Tempo total(s): 0.012841755000408739
# Saída: 62 2586
#
# value 2586
# Stderr:
# Tempo total(s): 0.012652284996875096
# Saída: 68 4170
#
# value 4170
# Stderr:
# Tempo total(s): 0.01189837000129046
# Saída: 183 5743
#
# value 5743
# Stderr:
# Tempo total(s): 0.01244884399784496
# Saída: 255 6664
#
# value 6664
# Stderr:
# Tempo total(s): 0.01390710499981651
# Saída: 477 9070
#
# value 9070
# Stderr:
# Tempo total(s): 0.012619811997865327
# Saída: 246 4094
#
# value 4094
# Stderr:
# Tempo total(s): 0.01305712300381856
# Saída: 439 12989
#
# value 12989
# Stderr:
# Tempo total(s): 0.013428678001218941
# Saída: 50 1140
#
# value 1140
# Stderr:
# Tempo total(s): 0.01360407899483107
# Saída: 330 7662
#
# value 7662
# Stderr:
# Tempo total(s): 0.013221371998952236
# Saída: 73 3686
#
# value 3686
# Stderr:
# Tempo total(s): 0.013188725999498274
# Saída: 213 4148
#
# value 4148
# Stderr:
# Tempo total(s): 0.013505872004316188
# Saída: 309 3552
#
# value 3552
# Stderr:
# Tempo total(s): 0.01259149099496426
# Saída: 115 5296
#
# value 5296
# Stderr:
# Tempo total(s): 0.012150354996265378
# Saída: 399 6007
#
# value 6007
# Stderr:
# Tempo total(s): 0.0124385759991128
# Saída: 385 5832
#
# value 5832
# Stderr:
# Tempo total(s): 0.012446565997379366
# Saída: 304 6708
#
# value 6708
# Stderr:
# Tempo total(s): 0.012133459000324365
# Saída: 666 2906
#
# value 2906
# Stderr:
# Tempo total(s): 0.01258724999934202
# Saída: 45 910
#
# value 910
# Stderr:
# Tempo total(s): 0.012146514003688935
# Saída: 149 1509
#
# value 1509
# Stderr:
# Tempo total(s): 0.012731820999761112
# Saída: 475 8560
#
# value 8560
# Stderr:
# Tempo total(s): 0.013348466003662907
# Saída: 387 5786
#
# value 5786
# Stderr:
# Tempo total(s): 0.01351784299913561
# Saída: 88 3032
#
# value 3032
# Stderr:
# Tempo total(s): 0.014709454000694677
# Saída: 362 7338
#
# value 7338
# Stderr:
# Tempo total(s): 0.014233405003324151
# Saída: 659 5116
#
# value 5116
# Stderr:
# Tempo total(s): 0.012969533003342804
# Saída: 502 5977
#
# value 5977
# Stderr:
# Tempo total(s): 0.013043626997387037
# Saída: 348 9313
#
# value 9313
# Stderr:
# Tempo total(s): 0.012752192000334617
# Saída: 438 4741
#
# value 4741
# Stderr:
# Tempo total(s): 0.012631491998035926
# Saída: 93 2652
#
# value 2652
# Stderr:
# Tempo total(s): 0.014194597002642695
# Saída: 207 4380
#
# value 4380
# Stderr:
# Tempo total(s): 0.013560660001530778
# Saída: 534 7370
#
# value 7370
# Stderr:
# Tempo total(s): 0.012631042998691555
# Saída: 13 3830
#
# value 3830
# Stderr:
# Tempo total(s): 0.012282313997275196
# Saída: 563 9211
#
# value 9211
# Stderr:
# Tempo total(s): 0.012247696999111213
# Saída: 975 6811
#
# value 6811
# Stderr:
# Tempo total(s): 0.012264473996765446
# Saída: 123 7487
#
# value 7487
# Stderr:
# Tempo total(s): 0.012885601994639728
# Saída: 282 5090
#
# value 5090
# Stderr:
# Tempo total(s): 0.012308394005231094
# Saída: 62 4172
#
# value 4172
# Stderr:
# Tempo total(s): 0.013495060004061088
# Saída: 623 6596
#
# value 6596
# Stderr:
# Tempo total(s): 0.013402350996329915
# Saída: 180 6470
#
# value 6470
# Stderr:
# Tempo total(s): 0.012851635998231359
# Saída: 715 7025
#
# value 7025
# Stderr:
# Tempo total(s): 0.012594961001013871
# Saída: 642 11727
#
# value 11727
# Stderr:
# Tempo total(s): 0.013532072000089101
# Saída: 413 8716
#
# value 8716
# Stderr:
# Tempo total(s): 0.013270570001623128
# Saída: 483 11029
#
# value 11029
# Stderr:
# Tempo total(s): 0.012544457997137215
# Saída: 26 2886
#
# value 2886
# Stderr:
# Tempo total(s): 0.013779016000626143
# Saída: 439 3718
#
# value 3718
# Stderr:
# Tempo total(s): 0.012029560006340034
# Saída: 711 5735
#
# value 5735
# Stderr:
# Tempo total(s): 0.012397309001244139
# Saída: 121 4117
#
# value 4117
# Stderr:
# Tempo total(s): 0.012093301003915258
# Saída: 992 17523
#
# value 17523
# Stderr:
# Tempo total(s): 0.011946154998440761
# Saída: 555 4760
#
# value 4760
# Stderr:
# Tempo total(s): 0.012614118997589685
# Saída: 66 3650
#
# value 3650
# Stderr:
# Tempo total(s): 0.01232449000235647
# Saída: 272 1794
#
# value 1794
# Stderr:
# Tempo total(s): 0.012296205997699872
# Saída: 284 14706
#
# value 14706
# Stderr:
# Tempo total(s): 0.012332066995440982
# Saída: 125 6032
#
# value 6032
# Stderr:
# Tempo total(s): 0.012945581998792477
# Saída: 958 13886
#
# value 13886
# Stderr:
# Tempo total(s): 0.012834439003199805
# Saída: 337 3505
#
# value 3505
# Stderr:
# Tempo total(s): 0.012610033998498693
# Saída: 540 9096
#
# value 9096
# Stderr:
# Tempo total(s): 0.01211982499808073
# Saída: 536 8623
#
# value 8623
# Stderr:
# Tempo total(s): 0.012478024000301957
# Saída: 128 3938
#
# value 3938
# Stderr:
# Tempo total(s): 0.011882300001161639
# Saída: 866 6465
#
# value 6465
# Stderr:
# Tempo total(s): 0.012412103998940438
# Saída: 880 14867
#
# value 14867
# Stderr:
# Tempo total(s): 0.012228939995111432
# Saída: 516 8385
#
# value 8385
# Stderr:
# Tempo total(s): 0.012303324998356402
# Saída: 154 4851
#
# value 4851
# Stderr:
# Tempo total(s): 0.012072056000761222
# Saída: 454 5539
#
# value 5539
# Stderr:
# Tempo total(s): 0.012117188001866452
# Saída: 1272 11254
#
# value 11254
# Stderr:
# Tempo total(s): 0.011782569999922998
# Saída: 301 3974
#
# value 3974
# Stderr:
# Tempo total(s): 0.012717458004772197
# Saída: 576 7483
#
# value 7483
# Stderr:
# Tempo total(s): 0.012209376000100747
# Saída: 429 8876
#
# value 8876
# Stderr:
# Tempo total(s): 0.012408028000209015
# Saída: 930 10346
#
# value 10346
# Stderr:
# Tempo total(s): 0.01190695799596142
# Saída: 370 9499
#
# value 9499
# Stderr:
# Tempo total(s): 0.011818528997537214
# Saída: 808 14546
#
# value 14546
# Stderr:
# Tempo total(s): 0.01229247899755137
# Saída: 194 3874
#
# value 3874
# Stderr:
# Tempo total(s): 0.012242705997778103
# Saída: 175 3559
#
# value 3559
# Stderr:
# Tempo total(s): 0.011864709995279554
# Saída: 431 4678
#
# value 4678
# Stderr:
# Tempo total(s): 0.011608734006586019
# Saída: 298 4768
#
# value 4768
# Stderr:
# Tempo total(s): 0.011487149997265078
# Saída: 367 7178
#
# value 7178
# Stderr:
# Tempo total(s): 0.011645956001302693
# Saída: 1059 10293
#
# value 10293
# Stderr:
# Tempo total(s): 0.012193560003652237
# Saída: 464 1988
#
# value 1988
# Stderr:
# Tempo total(s): 0.011608331005845685
# Saída: 852 10691
#
# value 10691
# Stderr:
# Tempo total(s): 0.011991838997346349
# Saída: 116 5159
#
# value 5159
# Stderr:
# Tempo total(s): 0.011551064999366645
# Saída: 792 9488
#
# value 9488
# Stderr:
# Tempo total(s): 0.012272068997845054
# Saída: 311 4561
#
# value 4561
# Stderr:
# Tempo total(s): 0.011469908997241873
# Saída: 776 18209
#
# value 18209
# Stderr:
# Tempo total(s): 0.011726758006261662
# Saída: 42 2940
#
# value 2940
# Stderr:
# Tempo total(s): 0.011623387996223755
# Saída: 252 4962
#
# value 4962
# Stderr:
# Tempo total(s): 0.012202333004097454
# Saída: 903 12047
#
# value 12047
# Stderr:
# Tempo total(s): 0.013043236001976766
# Saída: 1200 16028
#
# value 16028
# Stderr:
# Tempo total(s): 0.012820816999010276
# Saída: 893 8512
#
# value 8512
# Stderr:
# Tempo total(s): 0.013251952994323801
# Saída: 481 4371
#
# value 4371
# Stderr:
# Tempo total(s): 0.012721742001303937
# Saída: 622 12144
#
# value 12144
# Stderr:
# Tempo total(s): 0.013091933004034217
# Saída: 527 7415
#
# value 7415
# Stderr:
# Tempo total(s): 0.01202937999914866
# Saída: 307 8758
#
# value 8758
# Stderr:
# Tempo total(s): 0.012308716999541502
# Saída: 336 8367
#
# value 8367
# Stderr:
# Tempo total(s): 0.013772678998066112
# Saída: 21 1748
#
# value 1748
# Stderr:
# Tempo total(s): 0.012935345999721903
# Saída: 123 3274
#
# value 3274
# Stderr:
# Tempo total(s): 0.013569476999691688
# Saída: 387 10910
#
# value 10910
# Stderr:
# Tempo total(s): 0.01236146800511051
# Saída: 572 7841
#
# value 7841
# Stderr:
# Tempo total(s): 0.01187826399836922
# Saída: 636 14129
#
# value 14129
# Stderr:
# Tempo total(s): 0.012348224998277146
# Saída: 719 10916
#
# value 10916
# Stderr:
# Tempo total(s): 0.011792801000410691
# Saída: 496 6772
#
# value 6772
# Stderr:
# Tempo total(s): 0.012412602998665534
# Saída: 354 6457
#
# value 6457
# Stderr:
# Tempo total(s): 0.012261840005521663
# Saída: 29 5735
#
# value 5735
# Stderr:
# Tempo total(s): 0.012639799002499785
# Saída: 560 5057
#
# value 5057
# Stderr:
# Tempo total(s): 0.01195123099751072
# Saída: 51 3094
#
# value 3094
# Stderr:
# Tempo total(s): 0.011625097002252005
# Saída: 20 3404
#
# value 3404
# Stderr:
# Tempo total(s): 0.011591144000703935
# Saída: 207 4117
#
# value 4117
# Stderr:
# Tempo total(s): 0.012443654995877296
# Saída: 638 12466
#
# value 12466
# Stderr:
# Tempo total(s): 0.011994622000202071
# Saída: 21 1858
#
# value 1858
# Stderr:
# Tempo total(s): 0.012116513004002627
# Saída: 291 7239
#
# value 7239
# Stderr:
# Tempo total(s): 0.01203709100082051
# Saída: 147 7870
#
# value 7870
# Stderr:
# Tempo total(s): 0.01196184800210176
# Saída: 135 3598
#
# value 3598
# Stderr:
# Tempo total(s): 0.012015448999591172
# Saída: 265 8730
#
# value 8730
# Stderr:
# Tempo total(s): 0.012481622994528152
# Saída: 88 8147
#
# value 8147
# Stderr:
# Tempo total(s): 0.01236737799627008
# Saída: 864 12404
#
# value 12404
# Stderr:
# Tempo total(s): 0.013399082999967504
# Saída: 391 4552
#
# value 4552
# Stderr:
# Tempo total(s): 0.014064807000977453
# Saída: 358 8178
#
# value 8178
# Stderr:
# Tempo total(s): 0.0133873200029484
# Saída: 817 8472
#
# value 8472
# Stderr:
# Tempo total(s): 0.013334121002117172
# Saída: 284 17440
#
# value 17440
# Stderr:
# Tempo total(s): 0.013221364002674818
# Saída: 213 9951
#
# value 9951
# Stderr:
# Tempo total(s): 0.014034173000254668
# Saída: 178 5711
#
# value 5711
# Stderr:
# Tempo total(s): 0.013452274004521314
# Saída: 217 8401
#
# value 8401
# Stderr:
# Tempo total(s): 0.013121693998982664
# Saída: 721 7292
#
# value 7292
# Stderr:
# Tempo total(s): 0.012965906993485987
# Saída: 222 12007
#
# value 12007
# Stderr:
# Tempo total(s): 0.013573363001341932
# Saída: 329 3056
#
# value 3056
# Stderr:
# Tempo total(s): 0.012583809002535418
# Saída: 274 2877
#
# value 2877
# Stderr:
# Tempo total(s): 0.012473024995415471
# Saída: 320 3772
#
# value 3772
# Stderr:
# Tempo total(s): 0.0131001159970765
# Saída: 369 7809
#
# value 7809
# Stderr:
# Tempo total(s): 0.012679020001087338
# Saída: 482 7481
#
# value 7481
# Stderr:
# Tempo total(s): 0.012869149002654012
# Saída: 984 14017
#
# value 14017
# Stderr:
# Tempo total(s): 0.013384154000959825
# Saída: 690 18499
#
# value 18499
# Stderr:
# Tempo total(s): 0.012908646996947937
# Saída: 269 12787
#
# value 12787
# Stderr:
# Tempo total(s): 0.013047288994130213
# Saída: 317 3793
#
# value 3793
# Stderr:
# Tempo total(s): 0.012559353999677114
# Saída: 74 4788
#
# value 4788
# Stderr:
# Tempo total(s): 0.012888434001069982
# Saída: 318 5354
#
# value 5354
# Stderr:
# Tempo total(s): 0.012682998996751849
# Saída: 653 15491
#
# value 15491
# Stderr:
# Tempo total(s): 0.012696978999883868
# Saída: 915 12391
#
# value 12391
# Stderr:
# Tempo total(s): 0.013129596001817845
# Saída: 823 11290
#
# value 11290
# Stderr:
# Tempo total(s): 0.01226830699306447
# Saída: 270 5824
#
# value 5824
# Stderr:
# Tempo total(s): 0.012236023998411838
# Saída: 803 11189
#
# value 11189
# Stderr:
# Tempo total(s): 0.012134821001382079
# Saída: 733 15458
#
# value 15458
# Stderr:
# Tempo total(s): 0.012081057000614237
# Saída: 104 3858
#
# value 3858
# Stderr:
# Tempo total(s): 0.012452882998331916
# Saída: 66 7221
#
# value 7221
# Stderr:
# Tempo total(s): 0.012248228995304089
# Saída: 639 7024
#
# value 7024
# Stderr:
# Tempo total(s): 0.011960601004830096
# Saída: 434 5263
#
# value 5263
# Stderr:
# Tempo total(s): 0.012924535003548954
# Saída: 517 13028
#
# value 13028
# Stderr:
# Tempo total(s): 0.013060133998806123
# Saída: 19 6944
#
# value 6944
# Stderr:
# Tempo total(s): 0.012650691001908854
# Saída: 332 10041
#
# value 10041
# Stderr:
# Tempo total(s): 0.012207867002871353
# Saída: 1086 12639
#
# value 12639
# Stderr:
# Tempo total(s): 0.012593277999258135
# Saída: 113 5860
#
# value 5860
# Stderr:
# Tempo total(s): 0.012526664999313653
# Saída: 719 13417
#
# value 13417
# Stderr:
# Tempo total(s): 0.012185106999822892
# Saída: 396 13906
#
# value 13906
# Stderr:
# Tempo total(s): 0.01232326400349848
# Saída: 848 9021
#
# value 9021
# Stderr:
# Tempo total(s): 0.012195085000712425
# Saída: 423 4432
#
# value 4432
# Stderr:
# Tempo total(s): 0.011949715997616295
# Saída: 469 16405
#
# value 16405
# Stderr:
# Tempo total(s): 0.012123285996494815
# Saída: 468 10869
#
# value 10869
# Stderr:
# Tempo total(s): 0.01189146099932259
# Saída: 613 7890
#
# value 7890
# Stderr:
# Tempo total(s): 0.012107274000300094
# Saída: 585 12430
#
# value 12430
# Stderr:
# Tempo total(s): 0.014178706995153334
# Saída: 268 12247
#
# value 12247
# Stderr:
# Tempo total(s): 0.011938403004023712
# Saída: 1093 16501
#
# value 16501
# Stderr:
# Tempo total(s): 0.012166157997853588
# Saída: 1058 20112
#
# value 20112
# Stderr:
# Tempo total(s): 0.011684185999911278
# Saída: 497 6827
#
# value 6827
# Stderr:
# Tempo total(s): 0.014630428995587863
# Saída: 694 12925
#
# value 12925
# Stderr:
# Tempo total(s): 0.012361624001641758
# Saída: 807 10034
#
# value 10034
# Stderr:
# Tempo total(s): 0.012420788996678311
# Saída: 721 18540
#
# value 18540
# Stderr:
# Tempo total(s): 0.012177153999800794
# Saída: 321 7711
#
# value 7711
# Stderr:
# Tempo total(s): 0.012071062003087718
# Saída: 1368 10925
#
# value 10925
# Stderr:
# Tempo total(s): 0.01228758900106186
# Saída: 1025 8934
#
# value 8934
# Stderr:
# Tempo total(s): 0.012481297002523206
# Saída: 497 6734
#
# value 6734
# Stderr:
# Tempo total(s): 0.01264331800484797
# Saída: 1114 17171
#
# value 17171
# Stderr:
# Tempo total(s): 0.012520948999735992
# Saída: 1438 21650
#
# value 21650
# Stderr:
# Tempo total(s): 0.012096345999452751
# Saída: 1185 30581
#
# value 30581
# Stderr:
# Tempo total(s): 0.012291025996091776
# Saída: 627 6549
#
# value 6549
# Stderr:
# Tempo total(s): 0.012344681003014557
# Saída: 979 21655
#
# value 21655
# Stderr:
# Tempo total(s): 0.012486826999520417
# Saída: 482 6876
#
# value 6876
# Stderr:
# Tempo total(s): 0.013231666998763103
# Saída: 42 4483
#
# value 4483
# Stderr:
# Tempo total(s): 0.012230478998390026
# Saída: 507 10387
#
# value 10387
# Stderr:
# Tempo total(s): 0.01311743700352963
# Saída: 26 4499
#
# value 4499
# Stderr:
# Tempo total(s): 0.012699186001555063
# Saída: 740 6652
#
# value 6652
# Stderr:
# Tempo total(s): 0.012500690005254
# Saída: 326 4119
#
# value 4119
# Stderr:
# Tempo total(s): 0.012837536000006367
# Saída: 152 4707
#
# value 4707
# Stderr:
# Tempo total(s): 0.013015053002163768
# Saída: 134 5453
#
# value 5453
# Stderr:
# Tempo total(s): 0.013440572998661082
# Saída: 377 9640
#
# value 9640
# Stderr:
# Tempo total(s): 0.01296926799841458
# Saída: 472 4923
#
# value 4923
# Stderr:
# Tempo total(s): 0.012794696005585138
# Saída: 657 12300
#
# value 12300
# Stderr:
# Tempo total(s): 0.01287705799768446
# Saída: 586 8094
#
# value 8094
# Stderr:
# Tempo total(s): 0.012537425995105878
# Saída: 1293 3026
#
# value 3026
# Stderr:
# Tempo total(s): 0.012376609003695194
# Saída: 655 5839
#
# value 5839
# Stderr:
# Tempo total(s): 0.012526327998784836
# Saída: 1526 19115
#
# value 19115
# Stderr:
# Tempo total(s): 0.014498582000669558
# Saída: 456 13314
#
# value 13314
# Stderr:
# Tempo total(s): 0.012330147001193836
# Saída: 940 12586
#
# value 12586
# Stderr:
# Tempo total(s): 0.012202485995658208
# Saída: 504 8413
#
# value 8413
# Stderr:
# Tempo total(s): 0.012219005002407357
# Saída: 1585 9561
#
# value 9561
# Stderr:
# Tempo total(s): 0.012131468996813055
# Saída: 219 3711
#
# value 3711
# Stderr:
# Tempo total(s): 0.012613708000571933
# Saída: 781 9232
#
# value 9232
# Stderr:
# Tempo total(s): 0.012840802999562584
# Saída: 742 8716
#
# value 8716
# Stderr:
# Tempo total(s): 0.012516276001406368
# Saída: 605 15714
#
# value 15714
# Stderr:
# Tempo total(s): 0.012408481998136267
# Saída: 305 20812
#
# value 20812
# Stderr:
# Tempo total(s): 0.012676799000473693
# Saída: 284 8933
#
# value 8933
# Stderr:
# Tempo total(s): 0.013074836002488155
# Saída: 459 1231
#
# value 1231
# Stderr:
# Tempo total(s): 0.013046366999333259
# Saída: 345 5971
#
# value 5971
# Stderr:
# Tempo total(s): 0.015794585000548977
# Saída: 1330 24841
#
# value 24841
# Stderr:
# Tempo total(s): 0.01356990299973404
# Saída: 199 9051
#
# value 9051
# Stderr:
# Tempo total(s): 0.013167748002160806
# Saída: 138 3404
#
# value 3404
# Stderr:
# Tempo total(s): 0.015644011000404134
# Saída: 567 6439
#
# value 6439
# Stderr:
# Tempo total(s): 0.01941884300322272
# Saída: 915 13813
#
# value 13813
# Stderr:
# Tempo total(s): 0.016326439996191766
# Saída: 414 8637
#
# value 8637
# Stderr:
# Tempo total(s): 0.016439932995126583
# Saída: 737 10204
#
# value 10204
# Stderr:
# Tempo total(s): 0.014347910997457802
# Saída: 372 6228
#
# value 6228
# Stderr:
# Tempo total(s): 0.013844218003214337
# Saída: 110 4155
#
# value 4155
# Stderr:
# Tempo total(s): 0.012922626003273763
# Saída: 624 10715
#
# value 10715
# Stderr:
# Tempo total(s): 0.012409538998326752
# Saída: 417 8507
#
# value 8507
# Stderr:
# Tempo total(s): 0.012550375999126118
# Saída: 217 8161
#
# value 8161
# Stderr:
# Tempo total(s): 0.012173668001196347
# Saída: 1003 15231
#
# value 15231
# Stderr:
# Tempo total(s): 0.011771565004892182
# Saída: 1631 21884
#
# value 21884
# Stderr:
# Tempo total(s): 0.011789655000029597
# Saída: 1269 14963
#
# value 14963
# Stderr:
# Tempo total(s): 0.011983015006990172
# Saída: 674 12402
#
# value 12402
# Stderr:
# Tempo total(s): 0.011858395002491307
# Saída: 507 4209
#
# value 4209
# Stderr:
# Tempo total(s): 0.01234255400049733
# Saída: 482 8409
#
# value 8409
# Stderr:
# Tempo total(s): 0.0127184219963965
# Saída: 754 19425
#
# value 19425
# Stderr:
# Tempo total(s): 0.012114507997466717
# Saída: 903 11323
#
# value 11323
# Stderr:
# Tempo total(s): 0.012015678999887314
# Saída: 1032 21748
#
# value 21748
# Stderr:
# Tempo total(s): 0.011990156999672763
# Saída: 7 2478
#
# value 2478
# Stderr:
# Tempo total(s): 0.011806300004536752
# Saída: 371 12502
#
# value 12502
# Stderr:
# Tempo total(s): 0.012135056000261102
# Saída: 184 4249
#
# value 4249
# Stderr:
# Tempo total(s): 0.012929650998557918
# Saída: 452 7929
#
# value 7929
# Stderr:
# Tempo total(s): 0.011876320997544099
# Saída: 98 9238
#
# value 9238
# Stderr:
# Tempo total(s): 0.011904092003533151
# Saída: 712 7039
#
# value 7039
# Stderr:
# Tempo total(s): 0.011946981998335104
# Saída: 855 9958
#
# value 9958
# Stderr:
# Tempo total(s): 0.012540764997538645
# Saída: 33 3157
#
# value 3157
# Stderr:
# Tempo total(s): 0.011988999998720828
# Saída: 1050 10531
#
# value 10531
# Stderr:
# Tempo total(s): 0.012548529004561715
# Saída: 260 6104
#
# value 6104
# Stderr:
# Tempo total(s): 0.012044568997225724
# Saída: 790 11863
#
# value 11863
# Stderr:
# Tempo total(s): 0.011613738002779428
# Saída: 525 7286
#
# value 7286
# Stderr:
# Tempo total(s): 0.012190408997412305
# Saída: 437 9153
#
# value 9153
# Stderr:
# Tempo total(s): 0.013214717000664677
# Saída: 987 6168
#
# value 6168
# Stderr:
# Tempo total(s): 0.01295352400484262
# Saída: 763 8872
#
# value 8872
# Stderr:
# Tempo total(s): 0.012421478997566737
# Saída: 275 2574
#
# value 2574
# Stderr:
# Tempo total(s): 0.012054564998834394
# Saída: 852 10305
#
# value 10305
# Stderr:
# Tempo total(s): 0.012280078997719102
# Saída: 859 10510
#
# value 10510
# Stderr:
# Tempo total(s): 0.01188856899534585
# Saída: 175 5884
#
# value 5884
# Stderr:
# Tempo total(s): 0.011824483997770585
# Saída: 254 4239
#
# value 4239
# Stderr:
# Tempo total(s): 0.01206239299790468
# Saída: 1473 22810
#
# value 22810
# Stderr:
# Tempo total(s): 0.012008698999125045
# Saída: 31 4734
#
# value 4734
# Stderr:
# Tempo total(s): 0.01190119500097353
# Saída: 791 4250
#
# value 4250
# Stderr:
# Tempo total(s): 0.012465178995626047
# Saída: 505 11427
#
# value 11427
# Stderr:
# Tempo total(s): 0.011893863003933802
# Saída: 3 1421
#
# value 1421
# Stderr:
# Tempo total(s): 0.012115483004890848
# Saída: 1569 19132
#
# value 19132
# Stderr:
# Tempo total(s): 0.012842730997363105
# Saída: 1062 11922
#
# value 11922
# Stderr:
# Tempo total(s): 0.011652168002910912
# Saída: 182 3748
#
# value 3748
# Stderr:
# Tempo total(s): 0.01200795699696755
# Saída: 1290 18303
#
# value 18303
# Stderr:
# Tempo total(s): 0.012832050000724848
# Saída: 792 10344
#
# value 10344
# Stderr:
# Tempo total(s): 0.012009145997581072
# Saída: 1056 26304
#
# value 26304
# Stderr:
# Tempo total(s): 0.012047319003613666
# Saída: 935 14915
#
# value 14915
# Stderr:
# Tempo total(s): 0.012199944001622498
# Saída: 16 1135
#
# value 1135
# Stderr:
# Tempo total(s): 0.011971731000812724
# Saída: 487 7572
#
# value 7572
# Stderr:
# Tempo total(s): 0.011918383002921473
# Saída: 1837 30183
#
# value 30183
# Stderr:
# Tempo total(s): 0.01198983200447401
# Saída: 947 23860
#
# value 23860
# Stderr:
# Tempo total(s): 0.012242707001860254
# Saída: 149 18356
#
# value 18356
# Stderr:
# Tempo total(s): 0.011833692995423917
# Saída: 1220 6594
#
# value 6594
# Stderr:
# Tempo total(s): 0.011999414004094433
# Saída: 519 9166
#
# value 9166
# Stderr:
# Tempo total(s): 0.012167829998361412
# Saída: 108 20162
#
# value 20162
# Stderr:
# Tempo total(s): 0.012458131997846067
# Saída: 1596 16230
#
# value 16230
# Stderr:
# Tempo total(s): 0.013141174000338651
# Saída: 736 12250
#
# value 12250
# Stderr:
# Tempo total(s): 0.012903645998449065
# Saída: 670 14325
#
# value 14325
# Stderr:
# Tempo total(s): 0.01204083099582931
# Saída: 1074 13011
#
# value 13011
# Stderr:
# Tempo total(s): 0.011919083997781854
# Saída: 1204 18242
#
# value 18242
# Stderr:
# Tempo total(s): 0.012075443999492563
# Saída: 517 6856
#
# value 6856
# Stderr:
# Tempo total(s): 0.011948179002502002
# Saída: 699 12205
#
# value 12205
# Stderr:
# Tempo total(s): 0.012049691002175678
# Saída: 268 12566
#
# value 12566
# Stderr:
# Tempo total(s): 0.011970954998105299
# Saída: 483 16593
#
# value 16593
# Stderr:
# Tempo total(s): 0.012030333004076965
# Saída: 183 14403
#
# value 14403
# Stderr:
# Tempo total(s): 0.0121354130023974
# Saída: 1356 13210
#
# value 13210
# Stderr:
# Tempo total(s): 0.013279325001349207
# Saída: 44 2832
#
# value 2832
# Stderr:
# Tempo total(s): 0.011845424000057392
# Saída: 449 6130
#
# value 6130
# Stderr:
# Tempo total(s): 0.011953440000070259
# Saída: 980 14146
#
# value 14146
# Stderr:
# Tempo total(s): 0.011881669001013506
# Saída: 1574 18891
#
# value 18891
# Stderr:
# Tempo total(s): 0.012026999997033272
# Saída: 389 14464
#
# value 14464
# Stderr:
# Tempo total(s): 0.012346135998086538
# Saída: 133 12952
#
# value 12952
# Stderr:
# Tempo total(s): 0.01385904799826676
# Saída: 1349 17705
#
# value 17705
# Stderr:
# Tempo total(s): 0.012088180003047455
# Saída: 314 9353
#
# value 9353
# Stderr:
# Tempo total(s): 0.012143330000981223
# Saída: 1575 19151
#
# value 19151
# Stderr:
# Tempo total(s): 0.011990238999715075
# Saída: 515 3492
#
# value 3492
# Stderr:
# Tempo total(s): 0.012646318995393813
# Saída: 321 4173
#
# value 4173
# Stderr:
# ...
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# {'Tempo': 0.08358995800517732, 'Saida': 19019, 'n': 742, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08312511799886124, 'Saida': 6215, 'n': 743, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08460053100134246, 'Saida': 31233, 'n': 744, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08390386600513011, 'Saida': 12486, 'n': 745, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08692677900398849, 'Saida': 32270, 'n': 746, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08622681599808857, 'Saida': 17938, 'n': 747, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08554983000067296, 'Saida': 20625, 'n': 748, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.088319352005783, 'Saida': 21023, 'n': 749, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0833323510014452, 'Saida': 8062, 'n': 750, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08111816600285238, 'Saida': 12891, 'n': 751, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08698883400211344, 'Saida': 25073, 'n': 752, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08746703000360867, 'Saida': 25096, 'n': 753, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08676314400509, 'Saida': 29549, 'n': 754, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08821892899868544, 'Saida': 22510, 'n': 755, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08700330199644668, 'Saida': 19964, 'n': 756, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08743743899685796, 'Saida': 36720, 'n': 757, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08436918500228785, 'Saida': 28191, 'n': 758, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08790277899970533, 'Saida': 19253, 'n': 759, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.09083570400252938, 'Saida': 10303, 'n': 760, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0865898499978357, 'Saida': 22130, 'n': 761, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08445255499827908, 'Saida': 8451, 'n': 762, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08807434800110059, 'Saida': 14384, 'n': 763, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.09088055799657013, 'Saida': 40188, 'n': 764, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08615866499894764, 'Saida': 27098, 'n': 765, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0886395870038541, 'Saida': 18786, 'n': 766, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08672617000411265, 'Saida': 12179, 'n': 767, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08861984599934658, 'Saida': 17922, 'n': 768, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08922994299791753, 'Saida': 30520, 'n': 769, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08779753999988316, 'Saida': 19303, 'n': 770, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08603742199920816, 'Saida': 12073, 'n': 771, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08635817599861184, 'Saida': 31449, 'n': 772, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08718678099830868, 'Saida': 23869, 'n': 773, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.086978318002366, 'Saida': 18911, 'n': 774, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08622451200062642, 'Saida': 18933, 'n': 775, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08843087700370234, 'Saida': 33752, 'n': 776, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08779723800398642, 'Saida': 17586, 'n': 777, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08485628299968084, 'Saida': 20101, 'n': 778, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0861440520020551, 'Saida': 9902, 'n': 779, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08559789699938847, 'Saida': 23099, 'n': 780, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08716656800243072, 'Saida': 17999, 'n': 781, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08630888900370337, 'Saida': 32796, 'n': 782, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08453148099943064, 'Saida': 26661, 'n': 783, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08646779500122648, 'Saida': 11476, 'n': 784, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08971235900389729, 'Saida': 16660, 'n': 785, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.09015936699870508, 'Saida': 31828, 'n': 786, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08991021100518992, 'Saida': 26056, 'n': 787, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08952649599814322, 'Saida': 17589, 'n': 788, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08725475700339302, 'Saida': 29580, 'n': 789, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08736138899985235, 'Saida': 38983, 'n': 790, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08548722499836003, 'Saida': 10363, 'n': 791, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08667843100556638, 'Saida': 25930, 'n': 792, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0882218990009278, 'Saida': 10394, 'n': 793, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.09029141700011678, 'Saida': 25713, 'n': 794, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08812148699507816, 'Saida': 10932, 'n': 795, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.0892475069995271, 'Saida': 27776, 'n': 796, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.092441475004307, 'Saida': 28319, 'n': 797, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08864760700089391, 'Saida': 13583, 'n': 798, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.08832740600337274, 'Saida': 23000, 'n': 799, 'Algoritmo': 'Busca Local'}
# {'Tempo': 0.09003490000031888, 'Saida': 17027, 'n': 800, 'Algoritmo': 'Busca Local'}
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);
# /tmp/ipykernel_3413/4069739327.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(j, ignore_index = True);

# %%
df
# Out:
#       Saida     Tempo    n    Algoritmo
# 0        10   0.01502    5   Heuristica
# 1        25  0.013344    6   Heuristica
# 2        18  0.013217    7   Heuristica
# 3        31   0.01295    8   Heuristica
# 4        42  0.012509    9   Heuristica
# ...     ...       ...  ...          ...
# 2383  27776  0.093503  796  Busca Local
# 2384  28319  0.090871  797  Busca Local
# 2385  13583  0.090495  798  Busca Local
# 2386  23000  0.089234  799  Busca Local
# 2387  17027  0.090298  800  Busca Local
#
# [2388 rows x 4 columns]

# %%
algoritmos = list(df['Algoritmo'].value_counts().keys())

# %%
# for alg_ in algoritmos:

# %%
# df.plot.line(x = 'Tempo',y = 'Saida')
# plt.legend(['Algoritmo'])
# df_teste = df.loc[df['Algoritmo'] !='Busca Local']
df.pivot(index='n',columns='Algoritmo',values='Tempo').plot()
# Out:
# /home/marcelo/.local/lib/python3.8/site-packages/pandas/core/algorithms.py:798: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   uniques = Index(uniques)
# <AxesSubplot:xlabel='n'>
